# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim

# Environment for Cloud-Edge Task Offloading
class CloudEdgeEnvironment:
    def __init__(self, num_tasks, num_local_machines, num_edge_servers):
        self.num_tasks = num_tasks
        self.num_local_machines = num_local_machines
        self.num_edge_servers = num_edge_servers
        self.task_sizes = np.random.uniform(1, 10, size=num_tasks)  # Task sizes (δk)
        self.local_powers = np.random.uniform(1, 5, size=num_local_machines)  # Local machine powers (ri)
        self.edge_powers = np.random.uniform(5, 10, size=num_edge_servers)  # Edge server powers (rj)
        self.local_energy_rates = np.random.uniform(0.1, 0.5, size=num_local_machines)  # εik
        self.edge_energy_rates = np.random.uniform(0.2, 0.6, size=num_edge_servers)  # εjk
        self.offloading_costs = np.random.uniform(0.1, 0.3, size=num_edge_servers)  # γjk
        self.reset()  # Initialize allocations

    def reset(self):
        self.allocations = np.zeros((self.num_tasks, self.num_local_machines + self.num_edge_servers))
        return self._get_state()

    def _get_state(self):
        return np.concatenate([
            self.task_sizes,
            self.local_powers,
            self.edge_powers,
            self.allocations.flatten()
        ])

    def step(self, action):
        # Unpacking the action tuple
        task_idx, machine_type, machine_idx = action

        # Assign task to the corresponding machine
        if machine_type == "local":
            self.allocations[task_idx, machine_idx] = 1
        elif machine_type == "edge":
            self.allocations[task_idx, self.num_local_machines + machine_idx] = 1

        # Calculate total energy consumption
        total_energy = self._calculate_energy()
        reward = -total_energy  # Minimize energy
        done = np.all(self.allocations.sum(axis=1) == 1)  # All tasks assigned
        return self._get_state(), reward, done, {}

    def _calculate_energy(self):
        energy = 0
        for task_idx in range(self.num_tasks):
            for local_idx in range(self.num_local_machines):
                if self.allocations[task_idx, local_idx] == 1:
                    tik = self.task_sizes[task_idx] / self.local_powers[local_idx]
                    energy += tik * self.local_energy_rates[local_idx]
            for edge_idx in range(self.num_edge_servers):
                if self.allocations[task_idx, self.num_local_machines + edge_idx] == 1:
                    tjk = self.task_sizes[task_idx] / self.edge_powers[edge_idx]
                    energy += tjk * self.edge_energy_rates[edge_idx] + self.task_sizes[task_idx] * self.offloading_costs[edge_idx]
        return energy

# Q-Network for DQN
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# DQN Agent
class DQNAgent:
    def __init__(self, state_dim, action_dim, num_tasks, num_local_machines, num_edge_servers, 
                 lr=1e-3, gamma=0.99, epsilon_decay=0.995, batch_size=64, buffer_capacity=10000):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.num_tasks = num_tasks
        self.num_local_machines = num_local_machines
        self.num_edge_servers = num_edge_servers
        self.total_machines = num_local_machines + num_edge_servers  # Total possible assignments

        self.q_network = QNetwork(state_dim, action_dim)
        self.target_network = QNetwork(state_dim, action_dim)
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=lr)
        self.replay_buffer = []
        self.buffer_capacity = buffer_capacity
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = 1.0
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = 0.01

    def act(self, state):
        if random.random() < self.epsilon:
            action = random.randint(0, self.action_dim - 1)
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                action = torch.argmax(self.q_network(state_tensor)).item()

        # Convert action from an integer to (task_idx, machine_type, machine_idx)
        task_idx = action // self.total_machines
        machine_idx = action % self.total_machines
        machine_type = "local" if machine_idx < self.num_local_machines else "edge"
        machine_idx = machine_idx if machine_type == "local" else machine_idx - self.num_local_machines

        return (task_idx, machine_type, machine_idx)

    def store_transition(self, transition):
        if len(self.replay_buffer) >= self.buffer_capacity:
            self.replay_buffer.pop(0)
        self.replay_buffer.append(transition)

    def sample_batch(self):
        indices = np.random.choice(len(self.replay_buffer), self.batch_size)
        batch = [self.replay_buffer[idx] for idx in indices]
        return batch

    def learn(self):
        if len(self.replay_buffer) < self.batch_size:
            return
        batch = self.sample_batch()
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.FloatTensor(states)
        rewards = torch.FloatTensor(rewards)
        next_states = torch.FloatTensor(next_states)
        dones = torch.FloatTensor(dones)

        action_indices = [a[0] * self.total_machines + (a[2] if a[1] == "local" else self.num_local_machines + a[2]) for a in actions]
        actions = torch.LongTensor(action_indices)

        q_values = self.q_network(states).gather(1, actions.unsqueeze(1)).squeeze()
        with torch.no_grad():
            max_next_q_values = self.target_network(next_states).max(1)[0]
            target_q_values = rewards + self.gamma * max_next_q_values * (1 - dones)

        loss = nn.MSELoss()(q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_network(self):
        self.target_network.load_state_dict(self.q_network.state_dict())

# Initialize environment and agent
num_tasks = 10
num_local_machines = 3
num_edge_servers = 2
env = CloudEdgeEnvironment(num_tasks, num_local_machines, num_edge_servers)
state_dim = env._get_state().shape[0]
action_dim = num_tasks * (num_local_machines + num_edge_servers)
agent = DQNAgent(state_dim, action_dim, num_tasks, num_local_machines, num_edge_servers)
num_episodes = 500

# Training loop
for episode in range(num_episodes):
    state = env.reset()
    total_reward = 0
    for _ in range(num_tasks):
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.store_transition((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        agent.learn()
        if done:
            break
    agent.update_target_network()
    agent.epsilon = max(agent.epsilon_min, agent.epsilon * agent.epsilon_decay)
    print(f"Episode {episode}, Total Reward: {total_reward}")
# Out:
# Episode 0, Total Reward: -67.56208901235622
# Episode 1, Total Reward: -52.511140539251784
# Episode 2, Total Reward: -70.67182422367375
# Episode 3, Total Reward: -41.524338014442925
# Episode 4, Total Reward: -52.74281353476023
# Episode 5, Total Reward: -48.12339073872033
# Episode 6, Total Reward: -47.625246288775806
# Episode 7, Total Reward: -70.31245353237527
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_1292\1440850112.py:129: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   states = torch.FloatTensor(states)
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_1292\1440850112.py:132: DeprecationWarning: In future, it will be an error for 'np.bool' scalars to be interpreted as an index
#   dones = torch.FloatTensor(dones)
# Episode 8, Total Reward: -74.13191503169318
# Episode 9, Total Reward: -48.015092514160386
# Episode 10, Total Reward: -55.98013898056424
# Episode 11, Total Reward: -50.54647079895696
# Episode 12, Total Reward: -42.7210737624273
# Episode 13, Total Reward: -60.39831998881027
# Episode 14, Total Reward: -55.6800355163615
# Episode 15, Total Reward: -48.161208677279234
# Episode 16, Total Reward: -76.17439859507789
# Episode 17, Total Reward: -73.50316990472865
# Episode 18, Total Reward: -84.14441668520904
# Episode 19, Total Reward: -46.72254984758836
# Episode 20, Total Reward: -75.03104303397873
# Episode 21, Total Reward: -91.10621468176014
# Episode 22, Total Reward: -56.42720678824418
# Episode 23, Total Reward: -28.41135521222106
# Episode 24, Total Reward: -50.337395531006756
# Episode 25, Total Reward: -58.98141434669377
# Episode 26, Total Reward: -36.814089566390834
# Episode 27, Total Reward: -38.902013459108325
# Episode 28, Total Reward: -54.20878866652578
# Episode 29, Total Reward: -29.887179437164406
# Episode 30, Total Reward: -31.70768374382763
# Episode 31, Total Reward: -66.13632504273826
# Episode 32, Total Reward: -65.45026551032814
# Episode 33, Total Reward: -30.5270507543139
# Episode 34, Total Reward: -64.52385452281086
# Episode 35, Total Reward: -50.49224781718934
# Episode 36, Total Reward: -45.64170868356494
# Episode 37, Total Reward: -31.41789888425595
# Episode 38, Total Reward: -36.3055104318229
# Episode 39, Total Reward: -64.97214375707412
# Episode 40, Total Reward: -48.70664745513008
# Episode 41, Total Reward: -36.70953926669789
# Episode 42, Total Reward: -43.56880751115393
# Episode 43, Total Reward: -56.90896563924373
# Episode 44, Total Reward: -28.012655453445994
# Episode 45, Total Reward: -40.59373506518562
# Episode 46, Total Reward: -39.381269428756454
# Episode 47, Total Reward: -36.57875519551347
# Episode 48, Total Reward: -64.9630132110379
# Episode 49, Total Reward: -60.21918192688134
# Episode 50, Total Reward: -49.040733197708434
# Episode 51, Total Reward: -44.61321032335357
# Episode 52, Total Reward: -33.62749820615042
# Episode 53, Total Reward: -53.24865165616767
# Episode 54, Total Reward: -47.02741691200946
# Episode 55, Total Reward: -40.65255862540202
# Episode 56, Total Reward: -32.37470263449031
# Episode 57, Total Reward: -76.10510931824432
# Episode 58, Total Reward: -51.972548115346626
# Episode 59, Total Reward: -64.1859304953689
# Episode 60, Total Reward: -26.76476739269936
# Episode 61, Total Reward: -40.46184200562045
# Episode 62, Total Reward: -51.472355941661974
# Episode 63, Total Reward: -36.795885532426844
# Episode 64, Total Reward: -26.165515032025034
# Episode 65, Total Reward: -37.39861907325353
# Episode 66, Total Reward: -54.95725794305052
# Episode 67, Total Reward: -21.611038230443206
# Episode 68, Total Reward: -26.478650920352592
# Episode 69, Total Reward: -15.371957269037534
# Episode 70, Total Reward: -32.84457277506662
# Episode 71, Total Reward: -43.01915588224513
# Episode 72, Total Reward: -39.92166652648563
# Episode 73, Total Reward: -30.678858557925036
# Episode 74, Total Reward: -33.429228521970415
# Episode 75, Total Reward: -8.839410446155346
# Episode 76, Total Reward: -44.11454213407002
# Episode 77, Total Reward: -63.309828875308185
# Episode 78, Total Reward: -40.82337391510646
# Episode 79, Total Reward: -28.641949955210226
# Episode 80, Total Reward: -15.72135747838227
# Episode 81, Total Reward: -53.918076139032706
# Episode 82, Total Reward: -26.433067994815225
# Episode 83, Total Reward: -18.248031290089166
# Episode 84, Total Reward: -30.156185998401376
# Episode 85, Total Reward: -45.64921183285142
# Episode 86, Total Reward: -31.717688461657097
# Episode 87, Total Reward: -52.17477242111663
# Episode 88, Total Reward: -36.2501641788039
# Episode 89, Total Reward: -45.82137166335487
# Episode 90, Total Reward: -21.390309704145594
# Episode 91, Total Reward: -25.401080666748737
# Episode 92, Total Reward: -26.705019805268183
# Episode 93, Total Reward: -36.53874390054793
# Episode 94, Total Reward: -48.901345089824005
# Episode 95, Total Reward: -18.386309850456435
# Episode 96, Total Reward: -51.10225114742373
# Episode 97, Total Reward: -40.77906166393812
# Episode 98, Total Reward: -61.49695867076631
# Episode 99, Total Reward: -35.28855264019155
# Episode 100, Total Reward: -43.03112047081771
# Episode 101, Total Reward: -42.948942929778255
# Episode 102, Total Reward: -21.741586035418816
# Episode 103, Total Reward: -55.35395731222002
# Episode 104, Total Reward: -15.178805737926565
# Episode 105, Total Reward: -52.65354369976942
# Episode 106, Total Reward: -14.521723331070767
# Episode 107, Total Reward: -61.605789849895956
# Episode 108, Total Reward: -57.91933385759958
# Episode 109, Total Reward: -38.78348891526129
# Episode 110, Total Reward: -18.998202673646578
# Episode 111, Total Reward: -18.311337987582778
# Episode 112, Total Reward: -32.530370214919536
# Episode 113, Total Reward: -20.922218782131118
# Episode 114, Total Reward: -43.122728103622364
# Episode 115, Total Reward: -49.12877533106855
# Episode 116, Total Reward: -54.906151292779825
# Episode 117, Total Reward: -22.619177730295306
# Episode 118, Total Reward: -33.61390527670379
# Episode 119, Total Reward: -36.77209143055036
# Episode 120, Total Reward: -48.84404894401004
# Episode 121, Total Reward: -40.42192098890923
# Episode 122, Total Reward: -23.349858095160524
# Episode 123, Total Reward: -22.41753858642034
# Episode 124, Total Reward: -33.08403318754052
# Episode 125, Total Reward: -26.75052500251237
# Episode 126, Total Reward: -34.523845148028926
# Episode 127, Total Reward: -24.494228838657055
# Episode 128, Total Reward: -12.431373388558452
# Episode 129, Total Reward: -44.321148383869726
# Episode 130, Total Reward: -46.60386036075547
# Episode 131, Total Reward: -24.858317895065532
# Episode 132, Total Reward: -37.16189673558782
# Episode 133, Total Reward: -36.505222344178584
# Episode 134, Total Reward: -64.99057666602944
# Episode 135, Total Reward: -53.012741499253536
# Episode 136, Total Reward: -38.04904397501189
# Episode 137, Total Reward: -75.18063101131429
# Episode 138, Total Reward: -27.03296532046962
# Episode 139, Total Reward: -9.536867892913317
# Episode 140, Total Reward: -55.65875376353756
# Episode 141, Total Reward: -26.601126714777443
# Episode 142, Total Reward: -27.740103157883325
# Episode 143, Total Reward: -25.403490334621573
# Episode 144, Total Reward: -32.313279080508565
# Episode 145, Total Reward: -12.438691992071526
# Episode 146, Total Reward: -37.65364139546413
# Episode 147, Total Reward: -33.69014305119874
# Episode 148, Total Reward: -39.87744591786053
# Episode 149, Total Reward: -18.748575970298152
# Episode 150, Total Reward: -18.84721838016118
# Episode 151, Total Reward: -31.20914045121782
# Episode 152, Total Reward: -25.874900048526143
# Episode 153, Total Reward: -43.98769234788031
# Episode 154, Total Reward: -44.206679878244785
# Episode 155, Total Reward: -39.74214589867617
# Episode 156, Total Reward: -17.170952705217925
# Episode 157, Total Reward: -32.36024503681198
# Episode 158, Total Reward: -13.228344730696215
# Episode 159, Total Reward: -18.390674167096357
# Episode 160, Total Reward: -11.04510372856961
# Episode 161, Total Reward: -39.683404366016376
# Episode 162, Total Reward: -27.27193592927813
# Episode 163, Total Reward: -37.1373269967461
# Episode 164, Total Reward: -15.772355250914526
# Episode 165, Total Reward: -44.439793854379666
# Episode 166, Total Reward: -41.10320747187775
# Episode 167, Total Reward: -27.896632292573518
# Episode 168, Total Reward: -26.275945390707708
# Episode 169, Total Reward: -20.48412811999947
# Episode 170, Total Reward: -32.9475915708654
# Episode 171, Total Reward: -30.162688943526227
# Episode 172, Total Reward: -70.1100244140986
# Episode 173, Total Reward: -11.850752562839414
# Episode 174, Total Reward: -23.848037893292346
# Episode 175, Total Reward: -21.619632927432132
# Episode 176, Total Reward: -23.663695036033197
# Episode 177, Total Reward: -60.69894226824859
# Episode 178, Total Reward: -19.679442033611096
# Episode 179, Total Reward: -34.881090936056154
# Episode 180, Total Reward: -36.68855826326711
# Episode 181, Total Reward: -58.04426306432107
# Episode 182, Total Reward: -21.059200633087837
# Episode 183, Total Reward: -35.84477634965704
# Episode 184, Total Reward: -31.876446206778226
# Episode 185, Total Reward: -5.010341190951314
# Episode 186, Total Reward: -22.97489802764056
# Episode 187, Total Reward: -23.463262700195294
# Episode 188, Total Reward: -13.06616764081091
# Episode 189, Total Reward: -32.338821133179096
# Episode 190, Total Reward: -27.76492597427498
# Episode 191, Total Reward: -61.74459772030976
# Episode 192, Total Reward: -38.14662713319703
# Episode 193, Total Reward: -44.33018426055476
# Episode 194, Total Reward: -29.54433126384481
# Episode 195, Total Reward: -21.97958441490228
# Episode 196, Total Reward: -38.31589555213869
# Episode 197, Total Reward: -26.642747801908524
# Episode 198, Total Reward: -32.1748342568563
# Episode 199, Total Reward: -12.731263982890763
# Episode 200, Total Reward: -23.167063800498987
# Episode 201, Total Reward: -21.591189193227045
# Episode 202, Total Reward: -10.798857292802115
# Episode 203, Total Reward: -3.3783581832995413
# Episode 204, Total Reward: -8.384605050475015
# Episode 205, Total Reward: -10.809101252219294
# Episode 206, Total Reward: -52.0732067708132
# Episode 207, Total Reward: -6.200328469797986
# Episode 208, Total Reward: -48.014707040976084
# Episode 209, Total Reward: -5.605818942813954
# Episode 210, Total Reward: -16.87774884716611
# Episode 211, Total Reward: -3.7449559277475877
# Episode 212, Total Reward: -27.174856004581535
# Episode 213, Total Reward: -54.268675201551325
# Episode 214, Total Reward: -28.9095468986373
# Episode 215, Total Reward: -34.19920584567478
# Episode 216, Total Reward: -24.115416285688102
# Episode 217, Total Reward: -14.701923528529164
# Episode 218, Total Reward: -22.338399764341112
# Episode 219, Total Reward: -25.615084637787714
# Episode 220, Total Reward: -22.47863787390648
# Episode 221, Total Reward: -31.458301938591212
# Episode 222, Total Reward: -15.783230557251752
# Episode 223, Total Reward: -19.752358325550695
# Episode 224, Total Reward: -12.803990682684734
# Episode 225, Total Reward: -19.008547590026918
# Episode 226, Total Reward: -15.599088862114106
# Episode 227, Total Reward: -17.59963808453723
# Episode 228, Total Reward: -27.686610021627573
# Episode 229, Total Reward: -29.277600075357274
# Episode 230, Total Reward: -26.749695602470105
# Episode 231, Total Reward: -34.912929116512984
# Episode 232, Total Reward: -2.6800342300641926
# Episode 233, Total Reward: -14.942824400828847
# Episode 234, Total Reward: -25.86673582962636
# Episode 235, Total Reward: -15.268585688180139
# Episode 236, Total Reward: -34.250485109298715
# Episode 237, Total Reward: -25.212975081814307
# Episode 238, Total Reward: -32.73271260542682
# Episode 239, Total Reward: -9.384196062167403
# Episode 240, Total Reward: -17.086830773230233
# Episode 241, Total Reward: -13.051256411199942
# Episode 242, Total Reward: -21.913785444041824
# Episode 243, Total Reward: -18.14223036177203
# Episode 244, Total Reward: -19.959480359882157
# Episode 245, Total Reward: -26.724145583826846
# Episode 246, Total Reward: -22.71752480054998
# Episode 247, Total Reward: -51.893029975119774
# Episode 248, Total Reward: -18.358243785705483
# Episode 249, Total Reward: -16.36399054546556
# Episode 250, Total Reward: -17.549830352923546
# Episode 251, Total Reward: -24.376338177506682
# Episode 252, Total Reward: -17.792059093534945
# Episode 253, Total Reward: -8.360179867855077
# Episode 254, Total Reward: -7.904816387828605
# Episode 255, Total Reward: -17.33433675913504
# Episode 256, Total Reward: -12.261289546821247
# Episode 257, Total Reward: -17.05164472149375
# Episode 258, Total Reward: -18.259790930165252
# Episode 259, Total Reward: -29.708768145219924
# Episode 260, Total Reward: -35.455562803653784
# Episode 261, Total Reward: -8.145726268521218
# Episode 262, Total Reward: -2.6800342300641926
# Episode 263, Total Reward: -7.897724837329269
# Episode 264, Total Reward: -39.88717760825745
# Episode 265, Total Reward: -9.95373785187698
# Episode 266, Total Reward: -11.165013453004132
# Episode 267, Total Reward: -11.92530569986604
# Episode 268, Total Reward: -25.3164522100069
# Episode 269, Total Reward: -32.70079743906235
# Episode 270, Total Reward: -4.805289289949797
# Episode 271, Total Reward: -9.254305432552725
# Episode 272, Total Reward: -8.788542257041277
# Episode 273, Total Reward: -15.291939095218876
# Episode 274, Total Reward: -7.423014688098604
# Episode 275, Total Reward: -17.50572580814028
# Episode 276, Total Reward: -21.06831001826963
# Episode 277, Total Reward: -6.608560271491355
# Episode 278, Total Reward: -10.57656881811785
# Episode 279, Total Reward: -13.16210520156372
# Episode 280, Total Reward: -10.052688698445571
# Episode 281, Total Reward: -18.443754066113108
# Episode 282, Total Reward: -12.547159322549005
# Episode 283, Total Reward: -23.605311710630033
# Episode 284, Total Reward: -37.25469683164318
# Episode 285, Total Reward: -12.647088471359332
# Episode 286, Total Reward: -21.21128225436369
# Episode 287, Total Reward: -6.600885232036751
# Episode 288, Total Reward: -22.102792828265457
# Episode 289, Total Reward: -13.39008061102773
# Episode 290, Total Reward: -14.180296834190647
# Episode 291, Total Reward: -38.669364744534725
# Episode 292, Total Reward: -14.54524777588729
# Episode 293, Total Reward: -6.919681749339502
# Episode 294, Total Reward: -9.992297572246557
# Episode 295, Total Reward: -11.35017497818557
# Episode 296, Total Reward: -18.7922363299813
# Episode 297, Total Reward: -12.495944501175941
# Episode 298, Total Reward: -47.400083233173326
# Episode 299, Total Reward: -14.987214758852488
# Episode 300, Total Reward: -13.548305620675514
# Episode 301, Total Reward: -6.859725762582336
# Episode 302, Total Reward: -26.873589130890327
# Episode 303, Total Reward: -9.415572659343423
# Episode 304, Total Reward: -23.15094662981641
# Episode 305, Total Reward: -21.60125560239315
# Episode 306, Total Reward: -11.551499941369364
# Episode 307, Total Reward: -24.470853998820804
# Episode 308, Total Reward: -30.39746115230055
# Episode 309, Total Reward: -6.278964028795197
# Episode 310, Total Reward: -15.30833108210995
# Episode 311, Total Reward: -33.25108667761635
# Episode 312, Total Reward: -14.475927150266743
# Episode 313, Total Reward: -18.73420613340178
# Episode 314, Total Reward: -6.616415126765606
# Episode 315, Total Reward: -40.72659035284245
# Episode 316, Total Reward: -13.509384910586837
# Episode 317, Total Reward: -14.062889913227805
# Episode 318, Total Reward: -25.556655267787015
# Episode 319, Total Reward: -7.244655029915592
# Episode 320, Total Reward: -6.543370578729114
# Episode 321, Total Reward: -31.76207704576353
# Episode 322, Total Reward: -25.87984939757886
# Episode 323, Total Reward: -4.882070772706701
# Episode 324, Total Reward: -25.256500743016947
# Episode 325, Total Reward: -10.519665302699702
# Episode 326, Total Reward: -11.796815941160958
# Episode 327, Total Reward: -57.455334396649064
# Episode 328, Total Reward: -8.476909193081687
# Episode 329, Total Reward: -13.71733052556454
# Episode 330, Total Reward: -21.428567066119165
# Episode 331, Total Reward: -28.292939218829027
# Episode 332, Total Reward: -12.664417915742309
# Episode 333, Total Reward: -9.134176159111371
# Episode 334, Total Reward: -20.801255331046644
# Episode 335, Total Reward: -15.639002004753596
# Episode 336, Total Reward: -28.46093539604765
# Episode 337, Total Reward: -9.646012365350767
# Episode 338, Total Reward: -35.01214161120903
# Episode 339, Total Reward: -4.589490056599197
# Episode 340, Total Reward: -9.209635453555912
# Episode 341, Total Reward: -34.929608683844506
# Episode 342, Total Reward: -9.668872364990646
# Episode 343, Total Reward: -4.880952280672583
# Episode 344, Total Reward: -7.541957618321069
# Episode 345, Total Reward: -10.346130747828205
# Episode 346, Total Reward: -26.038675028968747
# Episode 347, Total Reward: -13.06801553677301
# Episode 348, Total Reward: -9.916918682213906
# Episode 349, Total Reward: -2.9509696532022662
# Episode 350, Total Reward: -23.996559000524147
# Episode 351, Total Reward: -1.262662393099714
# Episode 352, Total Reward: -8.633851178560924
# Episode 353, Total Reward: -22.671340697153198
# Episode 354, Total Reward: -7.105842648058121
# Episode 355, Total Reward: -7.358482667896578
# Episode 356, Total Reward: -2.9995763561174114
# Episode 357, Total Reward: -7.626726968125531
# Episode 358, Total Reward: -34.04100096704158
# Episode 359, Total Reward: -30.07771444204356
# Episode 360, Total Reward: -9.206178641828531
# Episode 361, Total Reward: -9.012916039094524
# Episode 362, Total Reward: -43.56659878865389
# Episode 363, Total Reward: -9.378525044783968
# Episode 364, Total Reward: -13.35462206473948
# Episode 365, Total Reward: -2.6800342300641926
# Episode 366, Total Reward: -11.376516123781942
# Episode 367, Total Reward: -7.984282837170781
# Episode 368, Total Reward: -45.27973608786125
# Episode 369, Total Reward: -22.854611050222523
# Episode 370, Total Reward: -6.142961303750537
# Episode 371, Total Reward: -15.276740269225048
# Episode 372, Total Reward: -6.874888872236376
# Episode 373, Total Reward: -22.795100056584374
# Episode 374, Total Reward: -26.099410798685426
# Episode 375, Total Reward: -4.695434771178339
# Episode 376, Total Reward: -26.595849242386652
# Episode 377, Total Reward: -28.311203350337596
# Episode 378, Total Reward: -8.409630305799322
# Episode 379, Total Reward: -13.036484129877318
# Episode 380, Total Reward: -5.84305971342325
# Episode 381, Total Reward: -16.37111249681907
# Episode 382, Total Reward: -11.343448478014803
# Episode 383, Total Reward: -7.232216428586606
# Episode 384, Total Reward: -13.59358513088704
# Episode 385, Total Reward: -15.40377028132071
# Episode 386, Total Reward: -7.262165052563375
# Episode 387, Total Reward: -7.8184177475266985
# Episode 388, Total Reward: -6.607601563022811
# Episode 389, Total Reward: -3.3401227532678677
# Episode 390, Total Reward: -7.232216428586606
# Episode 391, Total Reward: -18.409916083504545
# Episode 392, Total Reward: -24.982319343595346
# Episode 393, Total Reward: -14.818482654925587
# Episode 394, Total Reward: -15.082100574624008
# Episode 395, Total Reward: -13.192657442985217
# Episode 396, Total Reward: -15.22066744177528
# Episode 397, Total Reward: -10.182303205144171
# Episode 398, Total Reward: -27.119607904149646
# Episode 399, Total Reward: -8.744912616088106
# Episode 400, Total Reward: -4.25051011977121
# Episode 401, Total Reward: -7.503785369974839
# Episode 402, Total Reward: -6.394537503822563
# Episode 403, Total Reward: -14.744205007991384
# Episode 404, Total Reward: -5.197182823432385
# Episode 405, Total Reward: -4.25051011977121
# Episode 406, Total Reward: -26.53096383301733
# Episode 407, Total Reward: -4.25051011977121
# Episode 408, Total Reward: -8.732210279814039
# Episode 409, Total Reward: -5.866158564676074
# Episode 410, Total Reward: -8.732444038887376
# Episode 411, Total Reward: -9.42378049084998
# Episode 412, Total Reward: -13.196173631076114
# Episode 413, Total Reward: -9.511749383515943
# Episode 414, Total Reward: -16.371838402366706
# Episode 415, Total Reward: -13.36377655543004
# Episode 416, Total Reward: -7.38341191205721
# Episode 417, Total Reward: -5.209085825687515
# Episode 418, Total Reward: -6.265910660885357
# Episode 419, Total Reward: -11.100722012132909
# Episode 420, Total Reward: -4.861336007383795
# Episode 421, Total Reward: -39.83451742766266
# Episode 422, Total Reward: -34.991014616093096
# Episode 423, Total Reward: -10.716712261684865
# Episode 424, Total Reward: -12.139546242935296
# Episode 425, Total Reward: -13.27485599915794
# Episode 426, Total Reward: -24.22316767737767
# Episode 427, Total Reward: -23.745128194668453
# Episode 428, Total Reward: -12.918216734951821
# Episode 429, Total Reward: -14.509925257921974
# Episode 430, Total Reward: -5.57068716617856
# Episode 431, Total Reward: -23.02407827403935
# Episode 432, Total Reward: -3.275067107452466
# Episode 433, Total Reward: -31.86506311849517
# Episode 434, Total Reward: -9.184103883938867
# Episode 435, Total Reward: -13.518185003848279
# Episode 436, Total Reward: -5.267811228128828
# Episode 437, Total Reward: -8.533472868025324
# Episode 438, Total Reward: -23.17150061709782
# Episode 439, Total Reward: -5.134373794941011
# Episode 440, Total Reward: -25.085645792973196
# Episode 441, Total Reward: -10.182303205144171
# Episode 442, Total Reward: -10.355068643044614
# Episode 443, Total Reward: -23.02991606862007
# Episode 444, Total Reward: -16.799092490339163
# Episode 445, Total Reward: -21.963594464123688
# Episode 446, Total Reward: -4.25051011977121
# Episode 447, Total Reward: -16.51259015476155
# Episode 448, Total Reward: -4.25051011977121
# Episode 449, Total Reward: -4.25051011977121
# Episode 450, Total Reward: -12.062295254671174
# Episode 451, Total Reward: -4.25051011977121
# Episode 452, Total Reward: -16.486242731379424
# Episode 453, Total Reward: -8.4687453085946
# Episode 454, Total Reward: -11.359015513791924
# Episode 455, Total Reward: -15.279332980428098
# Episode 456, Total Reward: -9.129764270065039
# Episode 457, Total Reward: -12.36340600752697
# Episode 458, Total Reward: -9.573587606207909
# Episode 459, Total Reward: -8.574219655665189
# Episode 460, Total Reward: -24.141066829615948
# Episode 461, Total Reward: -7.444051004804601
# Episode 462, Total Reward: -31.658601420578556
# Episode 463, Total Reward: -9.126255226394646
# Episode 464, Total Reward: -14.096036154694609
# Episode 465, Total Reward: -9.755002428487948
# Episode 466, Total Reward: -14.435480304271563
# Episode 467, Total Reward: -19.234032515322188
# Episode 468, Total Reward: -8.833813362579079
# Episode 469, Total Reward: -11.01067124293498
# Episode 470, Total Reward: -5.138711377318582
# Episode 471, Total Reward: -6.4109218666006225
# Episode 472, Total Reward: -5.82268322923516
# Episode 473, Total Reward: -18.337411072071678
# Episode 474, Total Reward: -3.990061073045178
# Episode 475, Total Reward: -7.710837325451776
# Episode 476, Total Reward: -5.000436112513629
# Episode 477, Total Reward: -32.56671188380364
# Episode 478, Total Reward: -4.25051011977121
# Episode 479, Total Reward: -5.285872241953553
# Episode 480, Total Reward: -5.121846987411708
# Episode 481, Total Reward: -12.201615618913891
# Episode 482, Total Reward: -7.198070516478429
# Episode 483, Total Reward: -4.25051011977121
# Episode 484, Total Reward: -25.1220312916824
# Episode 485, Total Reward: -4.195013963544649
# Episode 486, Total Reward: -6.975568360311389
# Episode 487, Total Reward: -14.667449460032785
# Episode 488, Total Reward: -10.82645927430313
# Episode 489, Total Reward: -15.314271955753231
# Episode 490, Total Reward: -6.758433926424011
# Episode 491, Total Reward: -6.958360900080089
# Episode 492, Total Reward: -17.431786102880338
# Episode 493, Total Reward: -4.811539894800486
# Episode 494, Total Reward: -4.25051011977121
# Episode 495, Total Reward: -17.48644118449527
# Episode 496, Total Reward: -5.139549687744107
# Episode 497, Total Reward: -5.091207742433876
# Episode 498, Total Reward: -16.924859061921005
# Episode 499, Total Reward: -3.3910036945253905
