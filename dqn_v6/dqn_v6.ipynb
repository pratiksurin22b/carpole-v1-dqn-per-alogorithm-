# %%
import numpy as np
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

# -------------------------------
# Prioritized Replay Buffer (Fixed)
# -------------------------------
class PrioritizedReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.priorities = np.zeros(capacity)
        self.pos = 0
        self.max_priority = 1.0

    def add(self, experience):
        if len(self.buffer) < self.capacity:
            self.buffer.append(experience)
        else:
            self.buffer[self.pos] = experience
        self.priorities[self.pos] = self.max_priority
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size, alpha=0.6):
        priorities = self.priorities[:len(self.buffer)] ** alpha
        probs = priorities / priorities.sum()
        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]
        weights = (len(self.buffer) * probs[indices]) ** (-0.5)
        weights /= weights.max()
        return samples, indices, np.array(weights, dtype=np.float32)

    def update_priorities(self, indices, priorities):
        for idx, priority in zip(indices, priorities):
            self.priorities[idx] = priority
        self.max_priority = max(self.max_priority, np.max(priorities))

# -------------------------------------------
# Mobile Edge Computing Environment (Updated)
# -------------------------------------------
class MECEnvironment:
    def __init__(self, num_md=3, num_es=2, num_tasks=20):
        self.num_md = num_md
        self.num_es = num_es
        self.num_tasks = num_tasks
        
        # Mobile Devices (MD) parameters
        self.md_compute = np.random.uniform(1.0, 3.0, num_md)        # GHz
        self.md_battery = np.random.randint(3000, 5001, num_md)      # mAh
        self.md_energy_local = np.random.uniform(1000, 3000, num_md) # mA/s (processing)
        self.md_energy_tx = np.random.uniform(0.1, 0.3, num_md)      # mAh per MB (transmission)
        
        # Edge Servers (ES) parameters
        self.es_compute = np.random.uniform(3.0, 5.0, num_es)        # GHz
        self.es_battery = np.random.randint(10000, 20001, num_es)    # mAh
        self.es_energy_process = np.random.uniform(500, 1500, num_es) # mA/s (processing)
        
        # Task parameters
        self.task_requirements = np.random.randint(100, 501, num_tasks)  # MB
        self.task_to_md = np.random.randint(0, num_md, num_tasks)  # Assign tasks to MDs
        
        self.reset()

    def reset(self):
        # Reset batteries to initial values
        self.md_battery = np.random.randint(3000, 5001, self.num_md)
        self.es_battery = np.random.randint(10000, 20001, self.num_es)
        
        self.current_task = 0
        self.completed_tasks = 0
        self.total_energy = 0
        self.violations = 0
        return self._get_state()

    def _get_state(self):
        if self.current_task >= self.num_tasks:
            return np.zeros(self.state_size)
        
        md_idx = self.task_to_md[self.current_task]
        task_size = self.task_requirements[self.current_task]
        
        # Normalize values
        state = [
            self.md_battery[md_idx] / 5000,
            self.md_compute[md_idx] / 3.0,
            task_size / 500,
            self.md_energy_local[md_idx] / 3000,
            self.md_energy_tx[md_idx] / 0.3
        ]
        
        # Add ES parameters
        for es_idx in range(self.num_es):
            state.extend([
                self.es_battery[es_idx] / 20000,
                self.es_compute[es_idx] / 5.0,
                self.es_energy_process[es_idx] / 1500
            ])
        
        # Add task progress
        state.append(self.current_task / self.num_tasks)
        
        self.state_size = len(state)
        return np.array(state)

    def step(self, action):
        if self.current_task >= self.num_tasks:
            return np.zeros(self.state_size), 0, True, {}
        
        md_idx = self.task_to_md[self.current_task]
        task_size = self.task_requirements[self.current_task]
        reward = 0
        done = False
        success = False
        device_used = ""
        energy_consumed = 0
        
        # Capture initial battery states
        initial_md_battery = self.md_battery[md_idx]
        initial_es_battery = self.es_battery[action-1] if action != 0 else 0

        # Process current task
        if action == 0:  # Local processing
            task_cycles = task_size * 1e6  # Convert MB to cycles
            processing_time = task_cycles / (self.md_compute[md_idx] * 1e9)  # Seconds
            energy_needed = processing_time * self.md_energy_local[md_idx]  # mA
            
            if initial_md_battery >= energy_needed:
                # Successful local processing
                self.md_battery[md_idx] -= energy_needed
                self.total_energy += energy_needed
                self.completed_tasks += 1
                
                # Reward components
                task_value = (task_size / 500) * 15  # Base reward scaled by task size
                energy_efficiency = (energy_needed / task_size) * 3  # Penalize energy per MB
                battery_impact = (energy_needed / initial_md_battery) * 8  # Penalize battery drain
                
                reward = task_value - energy_efficiency - battery_impact
                success = True
                energy_consumed = energy_needed
                device_used = f"MD{md_idx}"
            else:
                # Failed local processing
                self.violations += 1
                reward = -(task_size / 500) * 15  # Penalty proportional to task size
                self.md_battery[md_idx] = 0
        else:  # Offload to ES
            es_idx = action - 1
            if es_idx >= self.num_es:
                es_idx = self.num_es - 1
                
            # Transmission energy (per-MB rate)
            tx_energy = task_size * self.md_energy_tx[md_idx]
            
            # Edge processing (time-based)
            task_cycles = task_size * 1e6  # Convert MB to cycles
            processing_time = task_cycles / (self.es_compute[es_idx] * 1e9)  # Seconds
            process_energy = processing_time * self.es_energy_process[es_idx]  # mA
            
            if (initial_md_battery >= tx_energy and 
                self.es_battery[es_idx] >= process_energy):
                
                # Successful offload
                self.md_battery[md_idx] -= tx_energy
                self.es_battery[es_idx] -= process_energy
                self.total_energy += tx_energy + process_energy
                self.completed_tasks += 1

                # Reward components
                task_value = (task_size / 500) * 15
                total_energy = tx_energy + process_energy
                energy_efficiency = (total_energy / task_size) * 2.5
                md_impact = (tx_energy / initial_md_battery) * 5
                es_impact = (process_energy / self.es_battery[es_idx]) * 5
                
                reward = task_value - energy_efficiency - md_impact - es_impact
                success = True
                energy_consumed = total_energy
                device_used = f"ES{es_idx}"
            else:
                # Failed offload
                self.violations += 1
                reward = -(task_size / 500) * 15
                if self.md_battery[md_idx] < tx_energy:
                    self.md_battery[md_idx] = 0
                if self.es_battery[es_idx] < process_energy:
                    self.es_battery[es_idx] = 0
        
        # Print step details
        print(f"Task {self.current_task+1} ({task_size}MB) - Device: {device_used if success else 'None'}")
        if success:
            print(f"  Energy used: {energy_consumed:.1f}mAh")
            print(f"  MD{md_idx} battery: {self.md_battery[md_idx]:.1f}mAh")
            if action != 0:
                print(f"  ES{es_idx} battery: {self.es_battery[es_idx]:.1f}mAh")
        else:
            print("  Failed - insufficient battery")
        
        # Move to next task
        self.current_task += 1
        done = self.current_task >= self.num_tasks
        
        # Get next state
        next_state = self._get_state()
        
        # Episode completion bonus
        if done:
            completion_ratio = self.completed_tasks / self.num_tasks
            reward += completion_ratio * 20  # Scaled completion bonus
            reward -= (self.violations / self.num_tasks) * 25  # Scaled violation penalty
        
        return next_state, reward, done, {}

# -------------------------------
# Dueling DQN Agent (Updated with Regularization)
# -------------------------------
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = PrioritizedReplayBuffer(10000)
        self.batch_size = 64
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_dueling_dqn()
        self.target_model = self._build_dueling_dqn()
        self.update_target_network()

    def _build_dueling_dqn(self):
        inputs = tf.keras.Input(shape=(self.state_size,))
        
        # Hidden layers with L2 regularization and dropout
        x = tf.keras.layers.Dense(128, activation='relu', 
                                 kernel_regularizer=tf.keras.regularizers.l2(0.01))(inputs)  # L2 regularization
        x = tf.keras.layers.Dropout(0.3)(x)  # Dropout layer (30% dropout rate)
        x = tf.keras.layers.Dense(64, activation='relu', 
                                 kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # L2 regularization
        x = tf.keras.layers.Dropout(0.2)(x)  # Dropout layer (20% dropout rate)
        
        # Value and Advantage streams
        value = tf.keras.layers.Dense(1)(x)
        advantage = tf.keras.layers.Dense(self.action_size)(x)
        
        # Combine streams
        mean_advantage = tf.keras.layers.Lambda(lambda a: tf.reduce_mean(a, axis=1, keepdims=True))(advantage)
        outputs = tf.keras.layers.Add()([value, tf.keras.layers.Subtract()([advantage, mean_advantage])])
        
        model = tf.keras.Model(inputs=inputs, outputs=outputs)
        model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def update_target_network(self):
        self.target_model.set_weights(self.model.get_weights())

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.randint(self.action_size)
        q_values = self.model.predict(state.reshape(1, -1), verbose=0)
        return np.argmax(q_values[0])

    def remember(self, state, action, reward, next_state, done):
        self.memory.add((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory.buffer) < self.batch_size:
            return

        samples, indices, weights = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*samples)
        
        states = np.array(states)
        next_states = np.array(next_states)
        
        current_q = self.model.predict(states, verbose=0)
        next_q = self.target_model.predict(next_states, verbose=0)
        
        td_errors = []
        for i in range(self.batch_size):
            if dones[i]:
                target = rewards[i]
            else:
                target = rewards[i] + self.gamma * np.max(next_q[i])
            delta = abs(current_q[i][actions[i]] - target)
            td_errors.append(delta)
            current_q[i][actions[i]] = target
        
        self.model.fit(states, current_q, sample_weight=weights,
                      batch_size=self.batch_size, verbose=0)
        
        self.memory.update_priorities(indices, td_errors)
        
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# -------------------------------
# Training and Evaluation (Updated)
# -------------------------------
def train_agent(episodes=100):
    env = MECEnvironment(num_md=3, num_es=2, num_tasks=10)
    state_size = env._get_state().shape[0]  # Initialize state size
    agent = DQNAgent(state_size=state_size, action_size=1 + env.num_es)
    
    rewards = []
    completion_rates = []
    energy_consumptions = []
    
    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        done = False
        
        print(f"\n=== Episode {episode+1} ===")
        print("Initial Batteries:")
        print(f"MDs: {env.md_battery}")
        print(f"ESs: {env.es_battery}")
        
        while not done:
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            
            if len(agent.memory.buffer) > agent.batch_size:
                agent.replay()
        
        if episode % 10 == 0:
            agent.update_target_network()
        
        rewards.append(total_reward)
        completion_rates.append(env.completed_tasks/env.num_tasks)
        energy_consumptions.append(env.total_energy)
        
        print("\nEpisode Summary:")
        print(f"Completed tasks: {env.completed_tasks}/{env.num_tasks}")
        print(f"Total energy consumed: {env.total_energy:.1f}mAh")
        print(f"Final MD batteries: {np.round(env.md_battery, 1)}")
        print(f"Final ES batteries: {np.round(env.es_battery, 1)}")
        print(f"Total reward: {total_reward:.1f}")
        print(f"Epsilon: {agent.epsilon:.3f}\n")
    
    # Plot training results
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,3,1)
    plt.plot(rewards)
    plt.title('Training Rewards')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    
    plt.subplot(1,3,2)
    plt.plot(completion_rates)
    plt.title('Task Completion Rate')
    plt.xlabel('Episode')
    plt.ylabel('Completion Rate')
    
    plt.subplot(1,3,3)
    plt.plot(energy_consumptions)
    plt.title('Energy Consumption')
    plt.xlabel('Episode')
    plt.ylabel('Total Energy (mAh)')
    
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    train_agent(episodes=200)
# Out:
# === Episode 1 ===
# Initial Batteries:
# MDs: [4133 3217 4498]
# ESs: [17388 18144]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4458.0mAh
#   ES1 battery: 18077.0mAh
# Task 2 (389MB) - Device: MD0
#   Energy used: 386.4mAh
#   MD0 battery: 3746.0mAh
# Task 3 (418MB) - Device: MD2
#   Energy used: 262.6mAh
#   MD2 battery: 4195.0mAh
# Task 4 (465MB) - Device: ES0
#   Energy used: 149.2mAh
#   MD1 battery: 3133.0mAh
#   ES0 battery: 17322.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3671.0mAh
#   ES1 battery: 17967.0mAh
# Task 6 (483MB) - Device: MD2
#   Energy used: 303.4mAh
#   MD2 battery: 3891.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3086.0mAh
#   ES1 battery: 17888.0mAh
# Task 8 (342MB) - Device: MD0
#   Energy used: 339.7mAh
#   MD0 battery: 3331.0mAh
# Task 9 (415MB) - Device: MD2
#   Energy used: 260.7mAh
#   MD2 battery: 3630.0mAh
# Task 10 (332MB) - Device: MD0
#   Energy used: 329.8mAh
#   MD0 battery: 3001.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 2446.6mAh
# Final MD batteries: [3001 3086 3630]
# Final ES batteries: [17322 17888]
# Total reward: 106.9
# Epsilon: 1.000
#
#
# === Episode 2 ===
# Initial Batteries:
# MDs: [4227 3686 3971]
# ESs: [12257 17878]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 3931.0mAh
#   ES1 battery: 17811.0mAh
# Task 2 (389MB) - Device: ES0
#   Energy used: 136.1mAh
#   MD0 battery: 4145.0mAh
#   ES0 battery: 12202.0mAh
# Task 3 (418MB) - Device: ES0
#   Energy used: 134.7mAh
#   MD2 battery: 3855.0mAh
#   ES0 battery: 12143.0mAh
# Task 4 (465MB) - Device: ES0
#   Energy used: 149.2mAh
#   MD1 battery: 3602.0mAh
#   ES0 battery: 12077.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 4070.0mAh
#   ES1 battery: 17701.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 3767.0mAh
#   ES1 battery: 17553.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3555.0mAh
#   ES1 battery: 17474.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3998.0mAh
#   ES1 battery: 17369.0mAh
# Task 9 (415MB) - Device: ES0
#   Energy used: 133.7mAh
#   MD2 battery: 3691.0mAh
#   ES0 battery: 12018.0mAh
# Task 10 (332MB) - Device: ES0
#   Energy used: 116.2mAh
#   MD0 battery: 3928.0mAh
#   ES0 battery: 11971.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1496.1mAh
# Final MD batteries: [3928 3555 3691]
# Final ES batteries: [11971 17369]
# Total reward: 118.7
# Epsilon: 1.000
#
#
# === Episode 3 ===
# Initial Batteries:
# MDs: [3041 4785 4172]
# ESs: [10670 19047]
# Task 1 (219MB) - Device: MD2
#   Energy used: 137.6mAh
#   MD2 battery: 4034.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 2959.0mAh
#   ES1 battery: 18928.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 3958.0mAh
#   ES1 battery: 18800.0mAh
# Task 4 (465MB) - Device: ES0
#   Energy used: 149.2mAh
#   MD1 battery: 4701.0mAh
#   ES0 battery: 10604.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 2884.0mAh
#   ES1 battery: 18690.0mAh
# Task 6 (483MB) - Device: ES0
#   Energy used: 155.6mAh
#   MD2 battery: 3870.0mAh
#   ES0 battery: 10536.0mAh
# Task 7 (256MB) - Device: MD1
#   Energy used: 280.1mAh
#   MD1 battery: 4420.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 2812.0mAh
#   ES1 battery: 18585.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3794.0mAh
#   ES1 battery: 18458.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 2742.0mAh
#   ES1 battery: 18356.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1859.2mAh
# Final MD batteries: [2742 4420 3794]
# Final ES batteries: [10536 18356]
# Total reward: 114.0
# Epsilon: 1.000
#
#
# === Episode 4 ===
# Initial Batteries:
# MDs: [3783 4953 4554]
# ESs: [17270 16247]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4514.0mAh
#   ES1 battery: 16180.0mAh
# Task 2 (389MB) - Device: MD0
#   Energy used: 386.4mAh
#   MD0 battery: 3396.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4438.0mAh
#   ES1 battery: 16052.0mAh
# Task 4 (465MB) - Device: ES0
#   Energy used: 149.2mAh
#   MD1 battery: 4869.0mAh
#   ES0 battery: 17204.0mAh
# Task 5 (357MB) - Device: MD0
#   Energy used: 354.6mAh
#   MD0 battery: 3041.0mAh
# Task 6 (483MB) - Device: MD2
#   Energy used: 303.4mAh
#   MD2 battery: 4134.0mAh
# Task 7 (256MB) - Device: ES0
#   Energy used: 82.2mAh
#   MD1 battery: 4822.0mAh
#   ES0 battery: 17167.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 
0mAh
# Task 8 (342MB) - Device: MD0
#   Energy used: 339.7mAh
#   MD0 battery: 3312.0mAh
# Task 9 (415MB) - Device: MD2
#   Energy used: 260.7mAh
#   MD2 battery: 3271.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3242.0mAh
#   ES1 battery: 14818.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 2008.9mAh
# Final MD batteries: [3242 4488 3271]
# Final ES batteries: [19619 14818]
# Total reward: 113.5
# Epsilon: 0.238
#
#
# === Episode 36 ===
# Initial Batteries:
# MDs: [4288 3230 4621]
# ESs: [10619 13383]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4581.0mAh
#   ES1 battery: 13316.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 4206.0mAh
#   ES1 battery: 13197.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4505.0mAh
#   ES1 battery: 13069.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3146.0mAh
#   ES1 battery: 12926.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 4131.0mAh
#   ES1 battery: 12816.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4417.0mAh
#   ES1 battery: 12668.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3099.0mAh
#   ES1 battery: 12589.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 4059.0mAh
#   ES1 battery: 12484.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4341.0mAh
#   ES1 battery: 12357.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3989.0mAh
#   ES1 battery: 12255.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3989 3099 4341]
# Final ES batteries: [10619 12255]
# Total reward: 116.5
# Epsilon: 0.227
#
#
# === Episode 37 ===
# Initial Batteries:
# MDs: [3270 3683 3788]
# ESs: [18218 18700]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 3748.0mAh
#   ES1 battery: 18633.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3188.0mAh
#   ES1 battery: 18514.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 3672.0mAh
#   ES1 battery: 18386.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3599.0mAh
#   ES1 battery: 18243.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3113.0mAh
#   ES1 battery: 18133.0mAh
# Task 6 (483MB) - Device: MD2
#   Energy used: 303.4mAh
#   MD2 battery: 3368.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3552.0mAh
#   ES1 battery: 18054.0mAh
# Task 8 (342MB) - Device: MD0
#   Energy used: 339.7mAh
#   MD0 battery: 2773.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3292.0mAh
#   ES1 battery: 17927.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 2703.0mAh
#   ES1 battery: 17825.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 2060.7mAh
# Final MD batteries: [2703 3552 3292]
# Final ES batteries: [18218 17825]
# Total reward: 112.9
# Epsilon: 0.216
#
#
# === Episode 38 ===
# Initial Batteries:
# MDs: [3212 4729 4916]
# ESs: [16439 11840]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4876.0mAh
#   ES1 battery: 11773.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3130.0mAh
#   ES1 battery: 11654.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4800.0mAh
#   ES1 battery: 11526.0mAh
# Task 4 (465MB) - Device: MD1
#   Energy used: 508.7mAh
#   MD1 battery: 4220.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3055.0mAh
#   ES1 battery: 11416.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4712.0mAh
#   ES1 battery: 11268.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 4173.0mAh
#   ES1 battery: 11189.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 2983.0mAh
#   ES1 battery: 11084.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4636.0mAh
#   ES1 battery: 10957.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 2913.0mAh
#   ES1 battery: 10855.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 2111.7mAh
# Final MD batteries: [2913 4173 4636]
# Final ES batteries: [16439 10855]
# Total reward: 113.6
# Epsilon: 0.205
#
#
# === Episode 39 ===
# Initial Batteries:
# MDs: [3624 4713 4586]
# ESs: [17479 17826]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4546.0mAh
#   ES1 battery: 17759.0mAh
# Task 2 (389MB) - Device: ES0
#   Energy used: 136.1mAh
#   MD0 battery: 3542.0mAh
#   ES0 battery: 17424.0mAh
# Task 3 (418MB) - Device: MD2
#   Energy used: 262.6mAh
#   MD2 battery: 4283.0mAh
# Task 4 (465MB) - Device: ES1
# ...
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3615.0mAh
#   ES1 battery: 11586.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3614.0mAh
#   ES1 battery: 11484.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3614 3459 3615]
# Final ES batteries: [14649 11484]
# Total reward: 116.4
# Epsilon: 0.010
#
#
# === Episode 189 ===
# Initial Batteries:
# MDs: [3731 3487 4485]
# ESs: [17346 17673]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4445.0mAh
#   ES1 battery: 17606.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3649.0mAh
#   ES1 battery: 17487.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4369.0mAh
#   ES1 battery: 17359.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3403.0mAh
#   ES1 battery: 17216.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3574.0mAh
#   ES1 battery: 17106.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4281.0mAh
#   ES1 battery: 16958.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3356.0mAh
#   ES1 battery: 16879.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3502.0mAh
#   ES1 battery: 16774.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4205.0mAh
#   ES1 battery: 16647.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3432.0mAh
#   ES1 battery: 16545.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3432 3356 4205]
# Final ES batteries: [17346 16545]
# Total reward: 116.6
# Epsilon: 0.010
#
#
# === Episode 190 ===
# Initial Batteries:
# MDs: [3537 3170 4802]
# ESs: [16330 10054]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4762.0mAh
#   ES1 battery: 9987.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3455.0mAh
#   ES1 battery: 9868.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4686.0mAh
#   ES1 battery: 9740.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3086.0mAh
#   ES1 battery: 9597.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3380.0mAh
#   ES1 battery: 9487.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4598.0mAh
#   ES1 battery: 9339.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3039.0mAh
#   ES1 battery: 9260.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3308.0mAh
#   ES1 battery: 9155.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4522.0mAh
#   ES1 battery: 9028.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3238.0mAh
#   ES1 battery: 8926.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3238 3039 4522]
# Final ES batteries: [16330  8926]
# Total reward: 116.3
# Epsilon: 0.010
#
#
# === Episode 191 ===
# Initial Batteries:
# MDs: [4600 4912 4059]
# ESs: [14212 16455]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4019.0mAh
#   ES1 battery: 16388.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 4518.0mAh
#   ES1 battery: 16269.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 3943.0mAh
#   ES1 battery: 16141.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 4828.0mAh
#   ES1 battery: 15998.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 4443.0mAh
#   ES1 battery: 15888.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 3855.0mAh
#   ES1 battery: 15740.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 4781.0mAh
#   ES1 battery: 15661.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 4371.0mAh
#   ES1 battery: 15556.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3779.0mAh
#   ES1 battery: 15429.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 4301.0mAh
#   ES1 battery: 15327.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [4301 4781 3779]
# Final ES batteries: [14212 15327]
# Total reward: 116.7
# Epsilon: 0.010
#
#
# === Episode 192 ===
# Initial Batteries:
# MDs: [3251 3741 4986]
# ESs: [13132 10016]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4946.0mAh
#   ES1 battery: 9949.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3169.0mAh
#   ES1 battery: 9830.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4870.0mAh
#   ES1 battery: 9702.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3657.0mAh
#   ES1 battery: 9559.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3094.0mAh
#   ES1 battery: 9449.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4782.0mAh
#   ES1 battery: 9301.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3610.0mAh
#   ES1 battery: 9222.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3022.0mAh
#   ES1 battery: 9117.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4706.0mAh
#   ES1 battery: 8990.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 2952.0mAh
#   ES1 battery: 8888.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [2952 3610 4706]
# Final ES batteries: [13132  8888]
# Total reward: 116.3
# Epsilon: 0.010
#
#
# === Episode 193 ===
# Initial Batteries:
# MDs: [4708 4393 4348]
# ESs: [17457 15233]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4308.0mAh
#   ES1 battery: 15166.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 4626.0mAh
#   ES1 battery: 15047.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4232.0mAh
#   ES1 battery: 14919.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 4309.0mAh
#   ES1 battery: 14776.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 4551.0mAh
#   ES1 battery: 14666.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4144.0mAh
#   ES1 battery: 14518.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 4262.0mAh
#   ES1 battery: 14439.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 4479.0mAh
#   ES1 battery: 14334.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4068.0mAh
#   ES1 battery: 14207.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 4409.0mAh
#   ES1 battery: 14105.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [4409 4262 4068]
# Final ES batteries: [17457 14105]
# Total reward: 116.6
# Epsilon: 0.010
#
#
# === Episode 194 ===
# Initial Batteries:
# MDs: [4077 3821 3992]
# ESs: [18214 18870]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 3952.0mAh
#   ES1 battery: 18803.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3995.0mAh
#   ES1 battery: 18684.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 3876.0mAh
#   ES1 battery: 18556.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3737.0mAh
#   ES1 battery: 18413.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3920.0mAh
#   ES1 battery: 18303.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 3788.0mAh
#   ES1 battery: 18155.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3690.0mAh
#   ES1 battery: 18076.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3848.0mAh
#   ES1 battery: 17971.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3712.0mAh
#   ES1 battery: 17844.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3778.0mAh
#   ES1 battery: 17742.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3778 3690 3712]
# Final ES batteries: [18214 17742]
# Total reward: 116.6
# Epsilon: 0.010
#
#
# === Episode 195 ===
# Initial Batteries:
# MDs: [4412 3150 4554]
# ESs: [13166 10812]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4514.0mAh
#   ES1 battery: 10745.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 4330.0mAh
#   ES1 battery: 10626.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4438.0mAh
#   ES1 battery: 10498.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3066.0mAh
#   ES1 battery: 10355.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 4255.0mAh
#   ES1 battery: 10245.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4350.0mAh
#   ES1 battery: 10097.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3019.0mAh
#   ES1 battery: 10018.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 4183.0mAh
#   ES1 battery: 9913.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4274.0mAh
#   ES1 battery: 9786.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 4113.0mAh
#   ES1 battery: 9684.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [4113 3019 4274]
# Final ES batteries: [13166  9684]
# Total reward: 116.4
# Epsilon: 0.010
#
#
# === Episode 196 ===
# Initial Batteries:
# MDs: [3764 4624 4301]
# ESs: [19675 10404]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4261.0mAh
#   ES1 battery: 10337.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3682.0mAh
#   ES1 battery: 10218.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4185.0mAh
#   ES1 battery: 10090.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 4540.0mAh
#   ES1 battery: 9947.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3607.0mAh
#   ES1 battery: 9837.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4097.0mAh
#   ES1 battery: 9689.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 4493.0mAh
#   ES1 battery: 9610.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3535.0mAh
#   ES1 battery: 9505.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4021.0mAh
#   ES1 battery: 9378.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3465.0mAh
#   ES1 battery: 9276.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3465 4493 4021]
# Final ES batteries: [19675  9276]
# Total reward: 116.4
# Epsilon: 0.010
#
#
# === Episode 197 ===
# Initial Batteries:
# MDs: [4013 3443 3992]
# ESs: [16399 11077]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 3952.0mAh
#   ES1 battery: 11010.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3931.0mAh
#   ES1 battery: 10891.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 3876.0mAh
#   ES1 battery: 10763.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3359.0mAh
#   ES1 battery: 10620.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 3856.0mAh
#   ES1 battery: 10510.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 3788.0mAh
#   ES1 battery: 10362.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3312.0mAh
#   ES1 battery: 10283.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 3784.0mAh
#   ES1 battery: 10178.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3712.0mAh
#   ES1 battery: 10051.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 3714.0mAh
#   ES1 battery: 9949.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [3714 3312 3712]
# Final ES batteries: [16399  9949]
# Total reward: 116.4
# Epsilon: 0.010
#
#
# === Episode 198 ===
# Initial Batteries:
# MDs: [3075 3584 4324]
# ESs: [17224 19013]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4284.0mAh
#   ES1 battery: 18946.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 2993.0mAh
#   ES1 battery: 18827.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4208.0mAh
#   ES1 battery: 18699.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3500.0mAh
#   ES1 battery: 18556.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 2918.0mAh
#   ES1 battery: 18446.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4120.0mAh
#   ES1 battery: 18298.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3453.0mAh
#   ES1 battery: 18219.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 2846.0mAh
#   ES1 battery: 18114.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4044.0mAh
#   ES1 battery: 17987.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 2776.0mAh
#   ES1 battery: 17885.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [2776 3453 4044]
# Final ES batteries: [17224 17885]
# Total reward: 116.5
# Epsilon: 0.010
#
#
# === Episode 199 ===
# Initial Batteries:
# MDs: [3090 3315 4293]
# ESs: [19420 14767]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 4253.0mAh
#   ES1 battery: 14700.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 3008.0mAh
#   ES1 battery: 14581.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 4177.0mAh
#   ES1 battery: 14453.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3231.0mAh
#   ES1 battery: 14310.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 2933.0mAh
#   ES1 battery: 14200.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 4089.0mAh
#   ES1 battery: 14052.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3184.0mAh
#   ES1 battery: 13973.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 2861.0mAh
#   ES1 battery: 13868.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 4013.0mAh
#   ES1 battery: 13741.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 2791.0mAh
#   ES1 battery: 13639.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [2791 3184 4013]
# Final ES batteries: [19420 13639]
# Total reward: 116.4
# Epsilon: 0.010
#
#
# === Episode 200 ===
# Initial Batteries:
# MDs: [4410 3837 3479]
# ESs: [19846 19740]
# Task 1 (219MB) - Device: ES1
#   Energy used: 106.7mAh
#   MD2 battery: 3439.0mAh
#   ES1 battery: 19673.0mAh
# Task 2 (389MB) - Device: ES1
#   Energy used: 200.3mAh
#   MD0 battery: 4328.0mAh
#   ES1 battery: 19554.0mAh
# Task 3 (418MB) - Device: ES1
#   Energy used: 203.6mAh
#   MD2 battery: 3363.0mAh
#   ES1 battery: 19426.0mAh
# Task 4 (465MB) - Device: ES1
#   Energy used: 225.9mAh
#   MD1 battery: 3753.0mAh
#   ES1 battery: 19283.0mAh
# Task 5 (357MB) - Device: ES1
#   Energy used: 183.8mAh
#   MD0 battery: 4253.0mAh
#   ES1 battery: 19173.0mAh
# Task 6 (483MB) - Device: ES1
#   Energy used: 235.2mAh
#   MD2 battery: 3275.0mAh
#   ES1 battery: 19025.0mAh
# Task 7 (256MB) - Device: ES1
#   Energy used: 124.4mAh
#   MD1 battery: 3706.0mAh
#   ES1 battery: 18946.0mAh
# Task 8 (342MB) - Device: ES1
#   Energy used: 176.1mAh
#   MD0 battery: 4181.0mAh
#   ES1 battery: 18841.0mAh
# Task 9 (415MB) - Device: ES1
#   Energy used: 202.1mAh
#   MD2 battery: 3199.0mAh
#   ES1 battery: 18714.0mAh
# Task 10 (332MB) - Device: ES1
#   Energy used: 170.9mAh
#   MD0 battery: 4111.0mAh
#   ES1 battery: 18612.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1828.9mAh
# Final MD batteries: [4111 3706 3199]
# Final ES batteries: [19846 18612]
# Total reward: 116.6
# Epsilon: 0.010
