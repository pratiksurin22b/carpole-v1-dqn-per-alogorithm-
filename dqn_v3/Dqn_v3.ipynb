# %%
import numpy as np
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

# -------------------------------
# Prioritized Replay Buffer (Fixed)
# -------------------------------
class PrioritizedReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.priorities = np.zeros(capacity)
        self.pos = 0
        self.max_priority = 1.0

    def add(self, experience):
        if len(self.buffer) < self.capacity:
            self.buffer.append(experience)
        else:
            self.buffer[self.pos] = experience
        self.priorities[self.pos] = self.max_priority
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size, alpha=0.6):
        priorities = self.priorities[:len(self.buffer)] ** alpha
        probs = priorities / priorities.sum()
        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]
        weights = (len(self.buffer) * probs[indices]) ** (-0.5)
        weights /= weights.max()
        return samples, indices, np.array(weights, dtype=np.float32)

    def update_priorities(self, indices, priorities):
        for idx, priority in zip(indices, priorities):
            self.priorities[idx] = priority
        self.max_priority = max(self.max_priority, np.max(priorities))

# -------------------------------------------
# Mobile Edge Computing Environment (Updated)
# -------------------------------------------
class MECEnvironment:
    def __init__(self, num_md=3, num_es=2, num_tasks=10):
        self.num_md = num_md
        self.num_es = num_es
        self.num_tasks = num_tasks
        
        # Mobile Devices (MD) parameters
        self.md_compute = np.random.uniform(1.0, 3.0, num_md)        # GHz
        self.md_battery = np.random.randint(3000, 5001, num_md)      # mAh
        self.md_energy_local = np.random.uniform(0.4, 0.6, num_md)   # mAh per MB (processing)
        self.md_energy_tx = np.random.uniform(0.1, 0.3, num_md)      # mAh per MB (transmission)
        
        # Edge Servers (ES) parameters
        self.es_compute = np.random.uniform(3.0, 5.0, num_es)        # GHz
        self.es_battery = np.random.randint(10000, 20001, num_es)    # mAh
        self.es_energy_process = np.random.uniform(0.05, 0.15, num_es) # mAh per MB (processing)
        
        # Task parameters
        self.task_requirements = np.random.randint(100, 501, num_tasks)  # MB
        self.task_to_md = np.random.randint(0, num_md, num_tasks)  # Assign tasks to MDs
        
        self.reset()

    def reset(self):
        # Reset batteries to initial values
        self.md_battery = np.random.randint(3000, 5001, self.num_md)
        self.es_battery = np.random.randint(10000, 20001, self.num_es)
        
        self.current_task = 0
        self.completed_tasks = 0
        self.total_energy = 0
        self.violations = 0
        return self._get_state()

    def _get_state(self):
        if self.current_task >= self.num_tasks:
            return np.zeros(self.state_size)
        
        md_idx = self.task_to_md[self.current_task]
        task_size = self.task_requirements[self.current_task]
        
        # Normalize values
        state = [
            self.md_battery[md_idx] / 5000,
            self.md_compute[md_idx] / 3.0,
            task_size / 500,
            self.md_energy_local[md_idx] / 0.6,
            self.md_energy_tx[md_idx] / 0.3
        ]
        
        # Add ES parameters
        for es_idx in range(self.num_es):
            state.extend([
                self.es_battery[es_idx] / 20000,
                self.es_compute[es_idx] / 5.0,
                self.es_energy_process[es_idx] / 0.15
            ])
        
        # Add task progress
        state.append(self.current_task / self.num_tasks)
        
        self.state_size = len(state)
        return np.array(state)

    def step(self, action):
        if self.current_task >= self.num_tasks:
            return np.zeros(self.state_size), 0, True, {}
        
        md_idx = self.task_to_md[self.current_task]
        task_size = self.task_requirements[self.current_task]
        reward = 0
        done = False
        success = False
        device_used = ""
        energy_consumed = 0
        
        # Process current task
        if action == 0:  # Local processing
            energy_needed = task_size * self.md_energy_local[md_idx]
            if self.md_battery[md_idx] >= energy_needed:
                self.md_battery[md_idx] -= energy_needed
                self.total_energy += energy_needed
                self.completed_tasks += 1
                reward = 5 - (energy_needed / 100)
                success = True
                energy_consumed = energy_needed
                device_used = f"MD{md_idx}"
            else:
                self.violations += 1
                reward = -10
                self.md_battery[md_idx] = 0
        else:  # Offload to ES
            es_idx = action - 1
            if es_idx >= self.num_es:
                es_idx = self.num_es - 1
                
            tx_energy = task_size * self.md_energy_tx[md_idx]
            process_energy = task_size * self.es_energy_process[es_idx]
            
            if (self.md_battery[md_idx] >= tx_energy and 
                self.es_battery[es_idx] >= process_energy):
                
                self.md_battery[md_idx] -= tx_energy
                self.es_battery[es_idx] -= process_energy
                self.total_energy += tx_energy + process_energy
                self.completed_tasks += 1
                reward = 5 - ((tx_energy + process_energy) / 100)
                success = True
                energy_consumed = tx_energy + process_energy
                device_used = f"ES{es_idx}"
            else:
                self.violations += 1
                reward = -10
                if self.md_battery[md_idx] < tx_energy:
                    self.md_battery[md_idx] = 0
                if self.es_battery[es_idx] < process_energy:
                    self.es_battery[es_idx] = 0
        
        # Print step details
        print(f"Task {self.current_task+1} ({task_size}MB) - Device: {device_used if success else 'None'}")
        if success:
            print(f"  Energy used: {energy_consumed:.1f}mAh")
            print(f"  MD{md_idx} battery: {self.md_battery[md_idx]:.1f}mAh")
            if action != 0:
                print(f"  ES{es_idx} battery: {self.es_battery[es_idx]:.1f}mAh")
        else:
            print("  Failed - insufficient battery")
        
        # Move to next task
        self.current_task += 1
        done = self.current_task >= self.num_tasks
        
        # Get next state
        next_state = self._get_state()
        
        # Add bonus reward if all tasks completed
        if done:
            if self.completed_tasks == self.num_tasks:
                reward += 20
            reward -= 2 * self.violations
        
        return next_state, reward, done, {}

# -------------------------------
# Dueling DQN Agent (Updated)
# -------------------------------
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = PrioritizedReplayBuffer(10000)
        self.batch_size = 64
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_dueling_dqn()
        self.target_model = self._build_dueling_dqn()
        self.update_target_network()

    def _build_dueling_dqn(self):
        inputs = tf.keras.Input(shape=(self.state_size,))
        x = tf.keras.layers.Dense(128, activation='relu')(inputs)
        x = tf.keras.layers.Dense(64, activation='relu')(x)
        
        # Value stream
        value = tf.keras.layers.Dense(1)(x)
        
        # Advantage stream
        advantage = tf.keras.layers.Dense(self.action_size)(x)
        
        # Combine streams
        mean_advantage = tf.keras.layers.Lambda(
            lambda a: tf.reduce_mean(a, axis=1, keepdims=True))(advantage)
        adjusted_advantage = tf.keras.layers.Subtract()([advantage, mean_advantage])
        outputs = tf.keras.layers.Add()([value, adjusted_advantage])
        
        model = tf.keras.Model(inputs=inputs, outputs=outputs)
        model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def update_target_network(self):
        self.target_model.set_weights(self.model.get_weights())

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.randint(self.action_size)
        q_values = self.model.predict(state.reshape(1, -1), verbose=0)
        return np.argmax(q_values[0])

    def remember(self, state, action, reward, next_state, done):
        self.memory.add((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory.buffer) < self.batch_size:
            return

        samples, indices, weights = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*samples)
        
        states = np.array(states)
        next_states = np.array(next_states)
        
        current_q = self.model.predict(states, verbose=0)
        next_q = self.target_model.predict(next_states, verbose=0)
        
        td_errors = []
        for i in range(self.batch_size):
            if dones[i]:
                target = rewards[i]
            else:
                target = rewards[i] + self.gamma * np.max(next_q[i])
            delta = abs(current_q[i][actions[i]] - target)
            td_errors.append(delta)
            current_q[i][actions[i]] = target
        
        self.model.fit(states, current_q, sample_weight=weights,
                      batch_size=self.batch_size, verbose=0)
        
        self.memory.update_priorities(indices, td_errors)
        
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# -------------------------------
# Training and Evaluation (Updated)
# -------------------------------
def train_agent(episodes=100):
    env = MECEnvironment(num_md=3, num_es=2, num_tasks=10)
    state_size = env._get_state().shape[0]  # Initialize state size
    agent = DQNAgent(state_size=state_size, action_size=1 + env.num_es)
    
    rewards = []
    completion_rates = []
    energy_consumptions = []
    
    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        done = False
        
        print(f"\n=== Episode {episode+1} ===")
        print("Initial Batteries:")
        print(f"MDs: {env.md_battery}")
        print(f"ESs: {env.es_battery}")
        
        while not done:
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            
            if len(agent.memory.buffer) > agent.batch_size:
                agent.replay()
        
        if episode % 10 == 0:
            agent.update_target_network()
        
        rewards.append(total_reward)
        completion_rates.append(env.completed_tasks/env.num_tasks)
        energy_consumptions.append(env.total_energy)
        
        print("\nEpisode Summary:")
        print(f"Completed tasks: {env.completed_tasks}/{env.num_tasks}")
        print(f"Total energy consumed: {env.total_energy:.1f}mAh")
        print(f"Final MD batteries: {np.round(env.md_battery, 1)}")
        print(f"Final ES batteries: {np.round(env.es_battery, 1)}")
        print(f"Total reward: {total_reward:.1f}")
        print(f"Epsilon: {agent.epsilon:.3f}\n")
    
    # Plot training results
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,3,1)
    plt.plot(rewards)
    plt.title('Training Rewards')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    
    plt.subplot(1,3,2)
    plt.plot(completion_rates)
    plt.title('Task Completion Rate')
    plt.xlabel('Episode')
    plt.ylabel('Completion Rate')
    
    plt.subplot(1,3,3)
    plt.plot(energy_consumptions)
    plt.title('Energy Consumption')
    plt.xlabel('Episode')
    plt.ylabel('Total Energy (mAh)')
    
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    train_agent(episodes=100)
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#
# === Episode 1 ===
# Initial Batteries:
# MDs: [4998 4156 3237]
# ESs: [13955 15183]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4973.0mAh
#   ES1 battery: 15161.0mAh
# Task 2 (113MB) - Device: MD0
#   Energy used: 63.2mAh
#   MD0 battery: 4909.0mAh
# Task 3 (445MB) - Device: MD2
#   Energy used: 187.9mAh
#   MD2 battery: 3049.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4095.0mAh
#   ES1 battery: 15112.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4037.0mAh
#   ES0 battery: 13921.0mAh
# Task 6 (466MB) - Device: MD0
#   Energy used: 260.5mAh
#   MD0 battery: 4648.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4629.0mAh
#   ES0 battery: 13909.0mAh
# Task 8 (441MB) - Device: MD0
#   Energy used: 246.5mAh
#   MD0 battery: 4382.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 2989.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3990.0mAh
#   ES1 battery: 15074.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1176.3mAh
# Final MD batteries: [4382 3990 2989]
# Final ES batteries: [13909 15074]
# Total reward: 58.2
# Epsilon: 1.000
#
#
# === Episode 2 ===
# Initial Batteries:
# MDs: [3081 3690 3763]
# ESs: [18479 14970]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 
0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3464.0mAh
#   ES0 battery: 13482.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 3405.0mAh
#   ES1 battery: 10551.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 4254.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3504.0mAh
#   ES1 battery: 10513.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 819.5mAh
# Final MD batteries: [3405 3504 4254]
# Final ES batteries: [13482 10513]
# Total reward: 61.8
# Epsilon: 1.000
#
#
# === Episode 7 ===
# Initial Batteries:
# MDs: [4026 3325 4171]
# ESs: [18528 17937]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4001.0mAh
#   ES0 battery: 18512.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 3985.0mAh
#   ES0 battery: 18502.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4069.0mAh
#   ES0 battery: 18464.0mAh
# Task 4 (418MB) - Device: MD1
#   Energy used: 185.6mAh
#   MD1 battery: 3139.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 3081.0mAh
#   ES0 battery: 18430.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 3923.0mAh
#   ES1 battery: 17882.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 3904.0mAh
#   ES1 battery: 17866.0mAh
# Task 8 (441MB) - Device: MD0
#   Energy used: 246.5mAh
#   MD0 battery: 3657.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4037.0mAh
#   ES1 battery: 17849.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3034.0mAh
#   ES1 battery: 17811.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1008.0mAh
# Final MD batteries: [3657 3034 4037]
# Final ES batteries: [18430 17811]
# Total reward: 59.9
# Epsilon: 0.970
#
#
# === Episode 8 ===
# Initial Batteries:
# MDs: [4064 4902 3379]
# ESs: [10480 12205]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4039.0mAh
#   ES1 battery: 12183.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4023.0mAh
#   ES1 battery: 12169.0mAh
# Task 3 (445MB) - Device: MD2
#   Energy used: 187.9mAh
#   MD2 battery: 3191.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4841.0mAh
#   ES1 battery: 12120.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4783.0mAh
#   ES0 battery: 10446.0mAh
# Task 6 (466MB) - Device: MD0
#   Energy used: 260.5mAh
#   MD0 battery: 3762.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 3743.0mAh
#   ES1 battery: 12104.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3684.0mAh
#   ES0 battery: 10408.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 3159.0mAh
#   ES0 battery: 10396.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4736.0mAh
#   ES1 battery: 12066.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 979.3mAh
# Final MD batteries: [3684 4736 3159]
# Final ES batteries: [10396 12066]
# Total reward: 60.2
# Epsilon: 0.923
#
#
# === Episode 9 ===
# Initial Batteries:
# MDs: [4822 3912 4076]
# ESs: [10204 19846]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4797.0mAh
#   ES1 battery: 19824.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4781.0mAh
#   ES1 battery: 19810.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3974.0mAh
#   ES0 battery: 10166.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 3851.0mAh
#   ES0 battery: 10130.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 3793.0mAh
#   ES1 battery: 19763.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4719.0mAh
#   ES1 battery: 19708.0mAh
# Task 7 (137MB) - Device: MD0
#   Energy used: 76.6mAh
#   MD0 battery: 4642.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4583.0mAh
#   ES1 battery: 19656.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 3914.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3746.0mAh
#   ES1 battery: 19618.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 856.7mAh
# Final MD batteries: [4583 3746 3914]
# Final ES batteries: [10130 19618]
# Total reward: 61.4
# Epsilon: 0.878
#
#
# === Episode 10 ===
# Initial Batteries:
# MDs: [3233 4297 4746]
# ESs: [17373 19496]
# Task 1 (183MB) - Device: MD0
#   Energy used: 102.3mAh
#   MD0 battery: 3130.0mAh
# Task 2 (113MB) - Device: MD0
#   Energy used: 63.2mAh
#   MD0 battery: 3066.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4644.0mAh
#   ES0 battery: 17335.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 4236.0mAh
#   ES0 battery: 17299.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4178.0mAh
#   ES0 battery: 17265.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 3004.0mAh
#   ES0 battery: 17225.0mAh
# Task 7 (137MB) - Device: MD0
#   Energy used: 76.6mAh
#   MD0 battery: 2927.0mAh
# Task 8 (441MB) - Device: MD0
#   Energy used: 246.5mAh
#   MD0 battery: 2680.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 4584.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4131.0mAh
#   ES1 battery: 19458.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1058.2mAh
# Final MD batteries: [2680 4131 4584]
# Final ES batteries: [17225 19458]
# Total reward: 59.4
# Epsilon: 0.835
#
#
# === Episode 11 ===
# Initial Batteries:
# MDs: [4009 3943 3765]
# ESs: [15370 15807]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 3984.0mAh
#   ES1 battery: 15785.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 3968.0mAh
#   ES1 battery: 15771.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3663.0mAh
#   ES0 battery: 15332.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 
0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 943.1mAh
# Final MD batteries: [3033 3978 3205]
# Final ES batteries: [18711 17573]
# Total reward: 60.6
# Epsilon: 0.650
#
#
# === Episode 16 ===
# Initial Batteries:
# MDs: [4945 3101 3750]
# ESs: [13926 19056]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4920.0mAh
#   ES1 battery: 19034.0mAh
# Task 2 (113MB) - Device: MD0
#   Energy used: 63.2mAh
#   MD0 battery: 4856.0mAh
# Task 3 (445MB) - Device: MD2
#   Energy used: 187.9mAh
#   MD2 battery: 3562.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 3040.0mAh
#   ES0 battery: 13890.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 2982.0mAh
#   ES0 battery: 13856.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4794.0mAh
#   ES0 battery: 13816.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4775.0mAh
#   ES0 battery: 13804.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 4716.0mAh
#   ES0 battery: 13766.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 3502.0mAh
# Task 10 (321MB) - Device: MD1
#   Energy used: 142.6mAh
#   MD1 battery: 2839.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 912.0mAh
# Final MD batteries: [4716 2839 3502]
# Final ES batteries: [13766 19034]
# Total reward: 60.9
# Epsilon: 0.618
#
#
# === Episode 17 ===
# Initial Batteries:
# MDs: [4336 3790 4824]
# ESs: [18386 19549]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4311.0mAh
#   ES1 battery: 19527.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4295.0mAh
#   ES0 battery: 18376.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4722.0mAh
#   ES0 battery: 18338.0mAh
# Task 4 (418MB) - Device: MD1
#   Energy used: 185.6mAh
#   MD1 battery: 3604.0mAh
# Task 5 (399MB) - Device: MD1
#   Energy used: 177.2mAh
#   MD1 battery: 3426.0mAh
# Task 6 (466MB) - Device: MD0
#   Energy used: 260.5mAh
#   MD0 battery: 4034.0mAh
# Task 7 (137MB) - Device: MD0
#   Energy used: 76.6mAh
#   MD0 battery: 3957.0mAh
# Task 8 (441MB) - Device: MD0
#   Energy used: 246.5mAh
#   MD0 battery: 3710.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 4690.0mAh
#   ES0 battery: 18326.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3379.0mAh
#   ES1 battery: 19489.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 1282.4mAh
# Final MD batteries: [3710 3379 4690]
# Final ES batteries: [18326 19489]
# Total reward: 57.2
# Epsilon: 0.588
#
#
# === Episode 18 ===
# Initial Batteries:
# MDs: [4949 4755 4007]
# ESs: [11713 12167]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4924.0mAh
#   ES1 battery: 12145.0mAh
# Task 2 (113MB) - Device: MD0
#   Energy used: 63.2mAh
#   MD0 battery: 4860.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3905.0mAh
#   ES0 battery: 11675.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4694.0mAh
#   ES1 battery: 12096.0mAh
# Task 5 (399MB) - Device: MD1
#   Energy used: 177.2mAh
#   MD1 battery: 4516.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4798.0mAh
#   ES1 battery: 12041.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4779.0mAh
#   ES0 battery: 11663.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4720.0mAh
#   ES1 battery: 11989.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 3845.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4469.0mAh
#   ES1 battery: 11951.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 931.4mAh
# Final MD batteries: [4720 4469 3845]
# Final ES batteries: [11663 11951]
# Total reward: 60.7
# Epsilon: 0.559
#
#
# === Episode 19 ===
# Initial Batteries:
# MDs: [3426 4550 4237]
# ESs: [15213 17249]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 3401.0mAh
#   ES1 battery: 17227.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 3385.0mAh
#   ES1 battery: 17213.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 4135.0mAh
#   ES1 battery: 17161.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4489.0mAh
#   ES1 battery: 17112.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 4431.0mAh
#   ES1 battery: 17065.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 3323.0mAh
#   ES1 battery: 17010.0mAh
# Task 7 (137MB) - Device: MD0
#   Energy used: 76.6mAh
#   MD0 battery: 3246.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 3187.0mAh
#   ES1 battery: 16958.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4103.0mAh
#   ES1 battery: 16941.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 4384.0mAh
#   ES0 battery: 15185.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 862.8mAh
# Final MD batteries: [3187 4384 4103]
# Final ES batteries: [15185 16941]
# Total reward: 61.4
# Epsilon: 0.532
#
#
# === Episode 20 ===
# Initial Batteries:
# MDs: [3853 3249 3823]
# ESs: [10867 16444]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 3828.0mAh
#   ES1 battery: 16422.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 3812.0mAh
#   ES0 battery: 10857.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 3721.0mAh
#   ES1 battery: 16370.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 
0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 4388.0mAh
#   ES0 battery: 11651.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 3657.0mAh
#   ES0 battery: 11623.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 799.9mAh
# Final MD batteries: [3915 3657 4388]
# Final ES batteries: [11623 10534]
# Total reward: 62.0
# Epsilon: 0.414
#
#
# === Episode 25 ===
# Initial Batteries:
# MDs: [3672 3369 4911]
# ESs: [10620 12662]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 3647.0mAh
#   ES0 battery: 10604.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 3631.0mAh
#   ES0 battery: 10594.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4809.0mAh
#   ES0 battery: 10556.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 3308.0mAh
#   ES1 battery: 12613.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 3250.0mAh
#   ES0 battery: 10522.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 3569.0mAh
#   ES0 battery: 10482.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3550.0mAh
#   ES0 battery: 10470.0mAh
# Task 8 (441MB) - Device: MD0
#   Energy used: 246.5mAh
#   MD0 battery: 3303.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 4749.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3203.0mAh
#   ES1 battery: 12575.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 923.3mAh
# Final MD batteries: [3303 3203 4749]
# Final ES batteries: [10470 12575]
# Total reward: 60.8
# Epsilon: 0.394
#
#
# === Episode 26 ===
# Initial Batteries:
# MDs: [4523 4000 4524]
# ESs: [11523 17345]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4498.0mAh
#   ES1 battery: 17323.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4482.0mAh
#   ES0 battery: 11513.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4422.0mAh
#   ES0 battery: 11475.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 3939.0mAh
#   ES1 battery: 17274.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 3881.0mAh
#   ES1 battery: 17227.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4420.0mAh
#   ES1 battery: 17172.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 4401.0mAh
#   ES1 battery: 17156.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4342.0mAh
#   ES1 battery: 17104.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4390.0mAh
#   ES1 battery: 17087.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3834.0mAh
#   ES1 battery: 17049.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 812.8mAh
# Final MD batteries: [4342 3834 4390]
# Final ES batteries: [11475 17049]
# Total reward: 61.9
# Epsilon: 0.374
#
#
# === Episode 27 ===
# Initial Batteries:
# MDs: [4580 4306 3723]
# ESs: [18819 13940]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4555.0mAh
#   ES1 battery: 13918.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4539.0mAh
#   ES1 battery: 13904.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 3621.0mAh
#   ES1 battery: 13852.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4245.0mAh
#   ES1 battery: 13803.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 4187.0mAh
#   ES1 battery: 13756.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4477.0mAh
#   ES1 battery: 13701.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 4458.0mAh
#   ES1 battery: 13685.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4399.0mAh
#   ES1 battery: 13633.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 3589.0mAh
#   ES0 battery: 18807.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4140.0mAh
#   ES1 battery: 13595.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 825.9mAh
# Final MD batteries: [4399 4140 3589]
# Final ES batteries: [18807 13595]
# Total reward: 61.7
# Epsilon: 0.356
#
#
# === Episode 28 ===
# Initial Batteries:
# MDs: [4455 4858 4974]
# ESs: [14406 10866]
# Task 1 (183MB) - Device: MD0
#   Energy used: 102.3mAh
#   MD0 battery: 4352.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4336.0mAh
#   ES0 battery: 14396.0mAh
# Task 3 (445MB) - Device: MD2
#   Energy used: 187.9mAh
#   MD2 battery: 4786.0mAh
# Task 4 (418MB) - Device: MD1
#   Energy used: 185.6mAh
#   MD1 battery: 4672.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4614.0mAh
#   ES0 battery: 14362.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4274.0mAh
#   ES0 battery: 14322.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 4255.0mAh
#   ES1 battery: 10850.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4196.0mAh
#   ES1 battery: 10798.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4754.0mAh
#   ES1 battery: 10781.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4567.0mAh
#   ES1 battery: 10743.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 968.3mAh
# Final MD batteries: [4196 4567 4754]
# Final ES batteries: [14322 10743]
# Total reward: 60.3
# Epsilon: 0.339
#
#
# === Episode 29 ===
# Initial Batteries:
# MDs: [3886 4601 4392]
# ESs: [14215 10448]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 
0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4241.0mAh
#   ES0 battery: 18908.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4222.0mAh
#   ES0 battery: 18896.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 4163.0mAh
#   ES0 battery: 18858.0mAh
# Task 9 (140MB) - Device: MD2
#   Energy used: 59.1mAh
#   MD2 battery: 4155.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 4536.0mAh
#   ES0 battery: 18830.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 749.3mAh
# Final MD batteries: [4163 4536 4155]
# Final ES batteries: [18830 17072]
# Total reward: 62.5
# Epsilon: 0.216
#
#
# === Episode 38 ===
# Initial Batteries:
# MDs: [4110 3282 3859]
# ESs: [15545 15031]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4085.0mAh
#   ES0 battery: 15529.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4069.0mAh
#   ES0 battery: 15519.0mAh
# Task 3 (445MB) - Device: MD2
#   Energy used: 187.9mAh
#   MD2 battery: 3671.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 3221.0mAh
#   ES0 battery: 15483.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 3163.0mAh
#   ES0 battery: 15449.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4007.0mAh
#   ES0 battery: 15409.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3988.0mAh
#   ES0 battery: 15397.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3929.0mAh
#   ES0 battery: 15359.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 3639.0mAh
#   ES1 battery: 15014.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3116.0mAh
#   ES1 battery: 14976.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 797.5mAh
# Final MD batteries: [3929 3116 3639]
# Final ES batteries: [15359 14976]
# Total reward: 62.0
# Epsilon: 0.205
#
#
# === Episode 39 ===
# Initial Batteries:
# MDs: [4159 3178 4018]
# ESs: [10974 16244]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4134.0mAh
#   ES0 battery: 10958.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4118.0mAh
#   ES0 battery: 10948.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3916.0mAh
#   ES0 battery: 10910.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
# ...
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3634.0mAh
#   ES0 battery: 10641.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 3404.0mAh
#   ES0 battery: 10629.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 3343.0mAh
#   ES0 battery: 10601.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 733.8mAh
# Final MD batteries: [3634 3343 3404]
# Final ES batteries: [10601 10610]
# Total reward: 62.7
# Epsilon: 0.017
#
#
# === Episode 89 ===
# Initial Batteries:
# MDs: [4770 3892 4368]
# ESs: [16330 12207]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4745.0mAh
#   ES0 battery: 16314.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4729.0mAh
#   ES0 battery: 16304.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4266.0mAh
#   ES0 battery: 16266.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 3831.0mAh
#   ES0 battery: 16230.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 3773.0mAh
#   ES0 battery: 16196.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4667.0mAh
#   ES0 battery: 16156.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4648.0mAh
#   ES0 battery: 16144.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 4589.0mAh
#   ES0 battery: 16106.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4234.0mAh
#   ES1 battery: 12190.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3726.0mAh
#   ES1 battery: 12152.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 748.3mAh
# Final MD batteries: [4589 3726 4234]
# Final ES batteries: [16106 12152]
# Total reward: 62.5
# Epsilon: 0.016
#
#
# === Episode 90 ===
# Initial Batteries:
# MDs: [4362 4184 4863]
# ESs: [10906 17379]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4337.0mAh
#   ES1 battery: 17357.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4321.0mAh
#   ES1 battery: 17343.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 4761.0mAh
#   ES1 battery: 17291.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4123.0mAh
#   ES1 battery: 17242.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 4065.0mAh
#   ES1 battery: 17195.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4259.0mAh
#   ES1 battery: 17140.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4240.0mAh
#   ES0 battery: 10894.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 4181.0mAh
#   ES0 battery: 10856.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 4729.0mAh
#   ES0 battery: 10844.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 4018.0mAh
#   ES0 battery: 10816.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 797.6mAh
# Final MD batteries: [4181 4018 4729]
# Final ES batteries: [10816 17140]
# Total reward: 62.0
# Epsilon: 0.015
#
#
# === Episode 91 ===
# Initial Batteries:
# MDs: [4849 4898 4233]
# ESs: [15590 18294]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4824.0mAh
#   ES0 battery: 15574.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4808.0mAh
#   ES0 battery: 15564.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4131.0mAh
#   ES0 battery: 15526.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4837.0mAh
#   ES1 battery: 18245.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 4779.0mAh
#   ES1 battery: 18198.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4746.0mAh
#   ES1 battery: 18143.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 4727.0mAh
#   ES1 battery: 18127.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4668.0mAh
#   ES1 battery: 18075.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4099.0mAh
#   ES1 battery: 18058.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4732.0mAh
#   ES1 battery: 18020.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 807.0mAh
# Final MD batteries: [4668 4732 4099]
# Final ES batteries: [15526 18020]
# Total reward: 61.9
# Epsilon: 0.014
#
#
# === Episode 92 ===
# Initial Batteries:
# MDs: [4557 3274 4872]
# ESs: [15432 10905]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4532.0mAh
#   ES1 battery: 10883.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4516.0mAh
#   ES1 battery: 10869.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 4770.0mAh
#   ES1 battery: 10817.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 3213.0mAh
#   ES1 battery: 10768.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 3155.0mAh
#   ES0 battery: 15398.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4454.0mAh
#   ES0 battery: 15358.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4435.0mAh
#   ES0 battery: 15346.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 4376.0mAh
#   ES0 battery: 15308.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 4738.0mAh
#   ES0 battery: 15296.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 3108.0mAh
#   ES0 battery: 15268.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 770.3mAh
# Final MD batteries: [4376 3108 4738]
# Final ES batteries: [15268 10768]
# Total reward: 62.3
# Epsilon: 0.014
#
#
# === Episode 93 ===
# Initial Batteries:
# MDs: [3825 4930 4253]
# ESs: [12371 10447]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 3800.0mAh
#   ES0 battery: 12355.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 3784.0mAh
#   ES0 battery: 12345.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4151.0mAh
#   ES0 battery: 12307.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 4869.0mAh
#   ES0 battery: 12271.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4811.0mAh
#   ES0 battery: 12237.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 3722.0mAh
#   ES0 battery: 12197.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3703.0mAh
#   ES0 battery: 12185.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3644.0mAh
#   ES0 battery: 12147.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 4119.0mAh
#   ES0 battery: 12135.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 4764.0mAh
#   ES0 battery: 12107.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 733.8mAh
# Final MD batteries: [3644 4764 4119]
# Final ES batteries: [12107 10447]
# Total reward: 62.7
# Epsilon: 0.013
#
#
# === Episode 94 ===
# Initial Batteries:
# MDs: [3400 4128 3782]
# ESs: [12664 19868]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 3375.0mAh
#   ES0 battery: 12648.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 3359.0mAh
#   ES0 battery: 12638.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3680.0mAh
#   ES0 battery: 12600.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 4067.0mAh
#   ES0 battery: 12564.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4009.0mAh
#   ES0 battery: 12530.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 3297.0mAh
#   ES0 battery: 12490.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3278.0mAh
#   ES0 battery: 12478.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3219.0mAh
#   ES0 battery: 12440.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 3648.0mAh
#   ES1 battery: 19851.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3962.0mAh
#   ES1 battery: 19813.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 748.3mAh
# Final MD batteries: [3219 3962 3648]
# Final ES batteries: [12440 19813]
# Total reward: 62.5
# Epsilon: 0.012
#
#
# === Episode 95 ===
# Initial Batteries:
# MDs: [4476 3339 4548]
# ESs: [18767 11192]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4451.0mAh
#   ES0 battery: 18751.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4435.0mAh
#   ES1 battery: 11178.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 4446.0mAh
#   ES1 battery: 11126.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 3278.0mAh
#   ES0 battery: 18715.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 3220.0mAh
#   ES1 battery: 11079.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 4373.0mAh
#   ES1 battery: 11024.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 4354.0mAh
#   ES1 battery: 11008.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 4295.0mAh
#   ES1 battery: 10956.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 4414.0mAh
#   ES1 battery: 10939.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 3173.0mAh
#   ES1 battery: 10901.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 811.4mAh
# Final MD batteries: [4295 3173 4414]
# Final ES batteries: [18715 10901]
# Total reward: 61.9
# Epsilon: 0.012
#
#
# === Episode 96 ===
# Initial Batteries:
# MDs: [3008 4280 3360]
# ESs: [17038 19543]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 2983.0mAh
#   ES0 battery: 17022.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 2967.0mAh
#   ES0 battery: 17012.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3258.0mAh
#   ES0 battery: 16974.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 4219.0mAh
#   ES0 battery: 16938.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4161.0mAh
#   ES0 battery: 16904.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 2905.0mAh
#   ES0 battery: 16864.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 2886.0mAh
#   ES0 battery: 16852.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 2827.0mAh
#   ES0 battery: 16814.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 3226.0mAh
#   ES0 battery: 16802.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 4114.0mAh
#   ES0 battery: 16774.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 733.8mAh
# Final MD batteries: [2827 4114 3226]
# Final ES batteries: [16774 19543]
# Total reward: 62.7
# Epsilon: 0.011
#
#
# === Episode 97 ===
# Initial Batteries:
# MDs: [3144 4305 3408]
# ESs: [19524 18770]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 3119.0mAh
#   ES0 battery: 19508.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 3103.0mAh
#   ES0 battery: 19498.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 3306.0mAh
#   ES0 battery: 19460.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 4244.0mAh
#   ES0 battery: 19424.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4186.0mAh
#   ES0 battery: 19390.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 3041.0mAh
#   ES0 battery: 19350.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3022.0mAh
#   ES0 battery: 19338.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 2963.0mAh
#   ES0 battery: 19300.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 3274.0mAh
#   ES0 battery: 19288.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4139.0mAh
#   ES1 battery: 18732.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 743.9mAh
# Final MD batteries: [2963 4139 3274]
# Final ES batteries: [19288 18732]
# Total reward: 62.6
# Epsilon: 0.011
#
#
# === Episode 98 ===
# Initial Batteries:
# MDs: [4070 4310 4040]
# ESs: [10092 17543]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4045.0mAh
#   ES0 battery: 10076.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4029.0mAh
#   ES1 battery: 17529.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 3938.0mAh
#   ES1 battery: 17477.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4249.0mAh
#   ES1 battery: 17428.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 4191.0mAh
#   ES1 battery: 17381.0mAh
# Task 6 (466MB) - Device: ES1
#   Energy used: 115.9mAh
#   MD0 battery: 3967.0mAh
#   ES1 battery: 17326.0mAh
# Task 7 (137MB) - Device: ES1
#   Energy used: 34.1mAh
#   MD0 battery: 3948.0mAh
#   ES1 battery: 17310.0mAh
# Task 8 (441MB) - Device: ES1
#   Energy used: 109.7mAh
#   MD0 battery: 3889.0mAh
#   ES1 battery: 17258.0mAh
# Task 9 (140MB) - Device: ES1
#   Energy used: 48.0mAh
#   MD2 battery: 3906.0mAh
#   ES1 battery: 17241.0mAh
# Task 10 (321MB) - Device: ES1
#   Energy used: 83.6mAh
#   MD1 battery: 4144.0mAh
#   ES1 battery: 17203.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 824.6mAh
# Final MD batteries: [3889 4144 3906]
# Final ES batteries: [10076 17203]
# Total reward: 61.8
# Epsilon: 0.010
#
#
# === Episode 99 ===
# Initial Batteries:
# MDs: [4100 4443 4103]
# ESs: [14069 19379]
# Task 1 (183MB) - Device: ES1
#   Energy used: 45.5mAh
#   MD0 battery: 4075.0mAh
#   ES1 battery: 19357.0mAh
# Task 2 (113MB) - Device: ES1
#   Energy used: 28.1mAh
#   MD0 battery: 4059.0mAh
#   ES1 battery: 19343.0mAh
# Task 3 (445MB) - Device: ES1
#   Energy used: 152.7mAh
#   MD2 battery: 4001.0mAh
#   ES1 battery: 19291.0mAh
# Task 4 (418MB) - Device: ES1
#   Energy used: 108.9mAh
#   MD1 battery: 4382.0mAh
#   ES1 battery: 19242.0mAh
# Task 5 (399MB) - Device: ES1
#   Energy used: 103.9mAh
#   MD1 battery: 4324.0mAh
#   ES1 battery: 19195.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 3997.0mAh
#   ES0 battery: 14029.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 3978.0mAh
#   ES0 battery: 14017.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3919.0mAh
#   ES0 battery: 13979.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 3969.0mAh
#   ES0 battery: 13967.0mAh
# Task 10 (321MB) - Device: MD1
#   Energy used: 142.6mAh
#   MD1 battery: 4181.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 852.0mAh
# Final MD batteries: [3919 4181 3969]
# Final ES batteries: [13967 19195]
# Total reward: 61.5
# Epsilon: 0.010
#
#
# === Episode 100 ===
# Initial Batteries:
# MDs: [4165 4381 4972]
# ESs: [15543 11937]
# Task 1 (183MB) - Device: ES0
#   Energy used: 39.7mAh
#   MD0 battery: 4140.0mAh
#   ES0 battery: 15527.0mAh
# Task 2 (113MB) - Device: ES0
#   Energy used: 24.5mAh
#   MD0 battery: 4124.0mAh
#   ES0 battery: 15517.0mAh
# Task 3 (445MB) - Device: ES0
#   Energy used: 138.6mAh
#   MD2 battery: 4870.0mAh
#   ES0 battery: 15479.0mAh
# Task 4 (418MB) - Device: ES0
#   Energy used: 95.7mAh
#   MD1 battery: 4320.0mAh
#   ES0 battery: 15443.0mAh
# Task 5 (399MB) - Device: ES0
#   Energy used: 91.3mAh
#   MD1 battery: 4262.0mAh
#   ES0 battery: 15409.0mAh
# Task 6 (466MB) - Device: ES0
#   Energy used: 101.2mAh
#   MD0 battery: 4062.0mAh
#   ES0 battery: 15369.0mAh
# Task 7 (137MB) - Device: ES0
#   Energy used: 29.8mAh
#   MD0 battery: 4043.0mAh
#   ES0 battery: 15357.0mAh
# Task 8 (441MB) - Device: ES0
#   Energy used: 95.8mAh
#   MD0 battery: 3984.0mAh
#   ES0 battery: 15319.0mAh
# Task 9 (140MB) - Device: ES0
#   Energy used: 43.6mAh
#   MD2 battery: 4838.0mAh
#   ES0 battery: 15307.0mAh
# Task 10 (321MB) - Device: ES0
#   Energy used: 73.5mAh
#   MD1 battery: 4215.0mAh
#   ES0 battery: 15279.0mAh
#
# Episode Summary:
# Completed tasks: 10/10
# Total energy consumed: 733.8mAh
# Final MD batteries: [3984 4215 4838]
# Final ES batteries: [15279 11937]
# Total reward: 62.7
# Epsilon: 0.010
